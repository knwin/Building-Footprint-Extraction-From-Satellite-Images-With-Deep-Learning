# %% [markdown]
# <a href="https://colab.research.google.com/github/Aye-Nyein-Thaw/Building-Footprint-Extraction-From-Satellite-Images-With-Deep-Learning/blob/toby/Toby's_Unet_Model_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import os
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

# %%
os.chdir('/content/drive/MyDrive/Unet_test/2.Image part')

# %%
ls
# Out:
# 'Binary Mask'/           Predictions14.png   Predictions3.png
#  final_predictions.png   Predictions15.png   Predictions4.png
#  img.png                 Predictions16.png   Predictions5.png
#  Predictions0.png        Predictions17.png   Predictions6.png
#  Predictions10.png       Predictions18.png   Predictions7.png
#  Predictions11.png       Predictions19.png   Predictions8.png
#  Predictions12.png       Predictions1.png    Predictions9.png
#  Predictions13.png       Predictions2.png   'Processed Image'/

# %%
train_path = 'Processed Image/'
test_path = 'Binary Mask/'

img_height =512 
img_width = 512
img_channels = 3

train_ids = sorted(next(os.walk(train_path)) [2])
print(train_ids[0])
test_ids = sorted(next(os.walk(test_path)) [2])
print(test_ids[0])
# Out:
# processed_image+final_00001_a0.png
# mask_00001_a0.png

# %%
sorted(test_ids)
# Out:
# ['mask_00001_a0.png',
#  'mask_00002_a0.png',
#  'mask_00003_a0.png',
#  'mask_00004_a0.png',
#  'mask_00005_a0.png',
#  'mask_00006_a0.png',
#  'mask_00007_a0.png',
#  'mask_00008_a0.png',
#  'mask_00009_a0.png',
#  'mask_00010_a0.png',
#  'mask_00011_a0.png',
#  'mask_00012_a0.png',
#  'mask_00013_a0.png',
#  'mask_00014_a0.png',
#  'mask_00015_a0.png',
#  'mask_00016_a0.png',
#  'mask_00017_a0.png',
#  'mask_00018_a0.png',
#  'mask_00019_a0.png',
#  'mask_00020_a0.png']

# %%
train_ids
# Out:
# ['processed_image+final_00001_a0.png',
#  'processed_image+final_00002_a0.png',
#  'processed_image+final_00003_a0.png',
#  'processed_image+final_00004_a0.png',
#  'processed_image+final_00005_a0.png',
#  'processed_image+final_00006_a0.png',
#  'processed_image+final_00007_a0.png',
#  'processed_image+final_00008_a0.png',
#  'processed_image+final_00009_a0.png',
#  'processed_image+final_00010_a0.png',
#  'processed_image+final_00011_a0.png',
#  'processed_image+final_00012_a0.png',
#  'processed_image+final_00013_a0.png',
#  'processed_image+final_00014_a0.png',
#  'processed_image+final_00015_a0.png',
#  'processed_image+final_00016_a0.png',
#  'processed_image+final_00017_a0.png',
#  'processed_image+final_00018_a0.png',
#  'processed_image+final_00019_a0.png',
#  'processed_image+final_00020_a0.png']

# %%
print(len(train_ids))
print(len(test_ids))
# Out:
# 20
# 20

# %%
X_train = np.zeros((len(train_ids),img_height, img_width, img_channels ), dtype=np.uint8)
Y_train = np.zeros((len(test_ids),img_height,img_width),dtype=np.bool)

# %%
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = train_path + id_
    print(path)
    img = Image.open(path)
    X_train[n]=img
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Processed Image/processed_image+final_00001_a0.png
#   5%|▌         | 1/20 [00:00<00:04,  4.50it/s]
# Processed Image/processed_image+final_00002_a0.png
#  10%|█         | 2/20 [00:00<00:04,  4.07it/s]
# Processed Image/processed_image+final_00003_a0.png
#  20%|██        | 4/20 [00:00<00:03,  4.59it/s]
# Processed Image/processed_image+final_00004_a0.png
# Processed Image/processed_image+final_00005_a0.png
#  30%|███       | 6/20 [00:01<00:02,  4.97it/s]
# Processed Image/processed_image+final_00006_a0.png
# Processed Image/processed_image+final_00007_a0.png
#  40%|████      | 8/20 [00:01<00:02,  5.21it/s]
# Processed Image/processed_image+final_00008_a0.png
# Processed Image/processed_image+final_00009_a0.png
#  45%|████▌     | 9/20 [00:01<00:02,  5.34it/s]
# Processed Image/processed_image+final_00010_a0.png
#  50%|█████     | 10/20 [00:02<00:02,  4.76it/s]
# Processed Image/processed_image+final_00011_a0.png
#  55%|█████▌    | 11/20 [00:02<00:02,  3.97it/s]
# Processed Image/processed_image+final_00012_a0.png
#  60%|██████    | 12/20 [00:02<00:02,  3.48it/s]
# Processed Image/processed_image+final_00013_a0.png
#  65%|██████▌   | 13/20 [00:03<00:01,  3.64it/s]
# Processed Image/processed_image+final_00014_a0.png
#  70%|███████   | 14/20 [00:03<00:01,  3.31it/s]
# Processed Image/processed_image+final_00015_a0.png
#  75%|███████▌  | 15/20 [00:03<00:01,  3.27it/s]
# Processed Image/processed_image+final_00016_a0.png
#  80%|████████  | 16/20 [00:04<00:01,  3.18it/s]
# Processed Image/processed_image+final_00017_a0.png
#  85%|████████▌ | 17/20 [00:04<00:00,  3.24it/s]
# Processed Image/processed_image+final_00018_a0.png
#  95%|█████████▌| 19/20 [00:04<00:00,  3.55it/s]
# Processed Image/processed_image+final_00019_a0.png
# 100%|██████████| 20/20 [00:05<00:00,  3.95it/s]
# Processed Image/processed_image+final_00020_a0.png

# %%
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path_test = test_path + id_
    print(path_test)
    mask = Image.open(path_test)
    Y_train[n]=mask
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Binary Mask/mask_00001_a0.png
#  10%|█         | 2/20 [00:00<00:04,  4.04it/s]
# Binary Mask/mask_00002_a0.png
# Binary Mask/mask_00003_a0.png
#  20%|██        | 4/20 [00:00<00:02,  5.81it/s]
# Binary Mask/mask_00004_a0.png
# Binary Mask/mask_00005_a0.png
#  25%|██▌       | 5/20 [00:01<00:03,  4.98it/s]
# Binary Mask/mask_00006_a0.png
#  35%|███▌      | 7/20 [00:01<00:02,  4.75it/s]
# Binary Mask/mask_00007_a0.png
# Binary Mask/mask_00008_a0.png
#  45%|████▌     | 9/20 [00:01<00:02,  4.50it/s]
# Binary Mask/mask_00009_a0.png
# Binary Mask/mask_00010_a0.png
#  50%|█████     | 10/20 [00:02<00:02,  4.13it/s]
# Binary Mask/mask_00011_a0.png
#  55%|█████▌    | 11/20 [00:02<00:02,  3.63it/s]
# Binary Mask/mask_00012_a0.png
#  65%|██████▌   | 13/20 [00:03<00:01,  3.94it/s]
# Binary Mask/mask_00013_a0.png
# Binary Mask/mask_00014_a0.png
#  70%|███████   | 14/20 [00:03<00:01,  4.33it/s]
# Binary Mask/mask_00015_a0.png
#  80%|████████  | 16/20 [00:03<00:00,  4.42it/s]
# Binary Mask/mask_00016_a0.png
# Binary Mask/mask_00017_a0.png
#  85%|████████▌ | 17/20 [00:04<00:00,  4.07it/s]
# Binary Mask/mask_00018_a0.png
#  95%|█████████▌| 19/20 [00:04<00:00,  4.45it/s]
# Binary Mask/mask_00019_a0.png
# Binary Mask/mask_00020_a0.png
# 100%|██████████| 20/20 [00:04<00:00,  4.13it/s]

# %%
def plotting (x ,y):
  n = np.random.randint(0,20)
  plt.subplot(121)
  plt.imshow(x[n])
  plt.subplot(122)
  plt.imshow(y[n])

plotting(X_train,Y_train)

# %%
#X_train_new = X_train/255
#Y_train_new = Y_train/255
#plotting(X_train_new,Y_t  rain_new)

#img_size = 512
#num_classes =2 

plotting(X_train,Y_train)

print(X_train[n].shape)
print(Y_train[n].shape)
# Out:
# (512, 512, 3)
# (512, 512)

# %%
#binary_crossentropy = tf.keras.losses.BinaryCrossentropy()
import keras.backend as K

# %%
    def dice_coef(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)  # -------------------------------------------------- explicit cast
        y_true = K.flatten(y_true)
        y_pred = K.flatten(y_pred)
        intersection = K.sum(y_true * y_pred)
        return 2.0 * intersection / (K.sum(y_true) + K.sum(y_pred) + 1.)

    ## function for measuring loss value
    def dice_coef_loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)  # -------------------------------------------------- explicit cast
        return 1.0 - dice_coef(y_true, y_pred)

    ## Merge loss
    def bce_dice_loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)  # -------------------------------------------------- explicit cast
        a = 0.5
        b = 1-a
        loss = a * K.binary_crossentropy(y_true, y_pred) + b * dice_coef_loss(y_true, y_pred)
        return loss

# %%
#Build the model
IMG_HEIGHT = 512
IMG_WIDTH = 512
IMG_CHANNELS = 3
inputs = tf.keras.layers.Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = tf.keras.layers.Lambda(lambda x: x / 255)(inputs)

#Contraction path
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)
 
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
c3 = tf.keras.layers.Dropout(0.2)(c3)
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)
 
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
c4 = tf.keras.layers.Dropout(0.2)(c4)
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c4)
 
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
c5 = tf.keras.layers.Dropout(0.3)(c5)
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

#Expansive path 
u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = tf.keras.layers.concatenate([u6, c4])
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
c6 = tf.keras.layers.Dropout(0.2)(c6)
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
 
u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
u7 = tf.keras.layers.concatenate([u7, c3])
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
c7 = tf.keras.layers.Dropout(0.2)(c7)
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)
 
u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
u8 = tf.keras.layers.concatenate([u8, c2])
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
c8 = tf.keras.layers.Dropout(0.1)(c8)
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
 
u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
c9 = tf.keras.layers.Dropout(0.1)(c9)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
 
outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)
 
model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
#model.summary()

# %%
history = model.fit(X_train,Y_train,epochs=150,verbose = 1, batch_size=4,validation_split=0.2)
# Out:
# Epoch 1/150
# 4/4 [==============================] - 38s 642ms/step - loss: 0.7578 - precision: 0.2056 - recall: 0.0428 - val_loss: 0.5859 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/150
# 4/4 [==============================] - 2s 423ms/step - loss: 0.4926 - precision: 0.0260 - recall: 4.9939e-05 - val_loss: 0.5617 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/150
# 4/4 [==============================] - 2s 431ms/step - loss: 0.4608 - precision: 0.0057 - recall: 3.5671e-06 - val_loss: 0.5303 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/150
# 4/4 [==============================] - 2s 425ms/step - loss: 0.4420 - precision: 0.0032 - recall: 1.7835e-06 - val_loss: 0.5116 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/150
# 4/4 [==============================] - 2s 424ms/step - loss: 0.4468 - precision: 0.0067 - recall: 1.7835e-06 - val_loss: 0.4960 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/150
# 4/4 [==============================] - 2s 428ms/step - loss: 0.4388 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.4796 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/150
# 4/4 [==============================] - 2s 430ms/step - loss: 0.4285 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.4567 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/150
# 4/4 [==============================] - 2s 425ms/step - loss: 0.4224 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.4232 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/150
# 4/4 [==============================] - 2s 427ms/step - loss: 0.4077 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.3628 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/150
# 4/4 [==============================] - 2s 429ms/step - loss: 0.3818 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.2644 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/150
# 4/4 [==============================] - 2s 436ms/step - loss: 0.3403 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.1907 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/150
# 4/4 [==============================] - 2s 429ms/step - loss: 0.2918 - precision: 0.3333 - recall: 1.7835e-06 - val_loss: 0.1219 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/150
# 4/4 [==============================] - 2s 425ms/step - loss: 0.2669 - precision: 0.9734 - recall: 0.0077 - val_loss: 0.1190 - val_precision: 0.9536 - val_recall: 0.0040
# Epoch 14/150
# 4/4 [==============================] - 2s 432ms/step - loss: 0.2264 - precision: 0.9536 - recall: 0.1526 - val_loss: 0.1335 - val_precision: 0.7524 - val_recall: 0.5427
# Epoch 15/150
# 4/4 [==============================] - 2s 436ms/step - loss: 0.2182 - precision: 0.8425 - recall: 0.4674 - val_loss: 0.0917 - val_precision: 0.8924 - val_recall: 0.6855
# Epoch 16/150
# 4/4 [==============================] - 2s 428ms/step - loss: 0.1951 - precision: 0.7627 - recall: 0.7031 - val_loss: 0.0892 - val_precision: 0.7920 - val_recall: 0.8665
# Epoch 17/150
# 4/4 [==============================] - 2s 431ms/step - loss: 0.1877 - precision: 0.8955 - recall: 0.7045 - val_loss: 0.1442 - val_precision: 0.4937 - val_recall: 0.9500
# Epoch 18/150
# 4/4 [==============================] - 2s 433ms/step - loss: 0.1840 - precision: 0.8380 - recall: 0.7648 - val_loss: 0.0689 - val_precision: 0.9136 - val_recall: 0.7309
# Epoch 19/150
# 4/4 [==============================] - 2s 435ms/step - loss: 0.1863 - precision: 0.8831 - recall: 0.6978 - val_loss: 0.1192 - val_precision: 0.5877 - val_recall: 0.9326
# Epoch 20/150
# 4/4 [==============================] - 2s 432ms/step - loss: 0.1779 - precision: 0.8871 - recall: 0.7206 - val_loss: 0.0693 - val_precision: 0.9007 - val_recall: 0.7660
# Epoch 21/150
# 4/4 [==============================] - 2s 430ms/step - loss: 0.1681 - precision: 0.8610 - recall: 0.7521 - val_loss: 0.0851 - val_precision: 0.7501 - val_recall: 0.9110
# Epoch 22/150
# 4/4 [==============================] - 2s 434ms/step - loss: 0.1603 - precision: 0.8848 - recall: 0.7639 - val_loss: 0.0670 - val_precision: 0.8611 - val_recall: 0.8723
# Epoch 23/150
# 4/4 [==============================] - 2s 435ms/step - loss: 0.1560 - precision: 0.8498 - recall: 0.8052 - val_loss: 0.0695 - val_precision: 0.8440 - val_recall: 0.8903
# Epoch 24/150
# 4/4 [==============================] - 2s 433ms/step - loss: 0.1521 - precision: 0.8788 - recall: 0.7812 - val_loss: 0.0648 - val_precision: 0.8874 - val_recall: 0.8376
# Epoch 25/150
# 4/4 [==============================] - 2s 430ms/step - loss: 0.1578 - precision: 0.9085 - recall: 0.7354 - val_loss: 0.1056 - val_precision: 0.5979 - val_recall: 0.9521
# Epoch 26/150
# 4/4 [==============================] - 2s 435ms/step - loss: 0.1631 - precision: 0.8172 - recall: 0.8137 - val_loss: 0.0636 - val_precision: 0.9117 - val_recall: 0.7670
# Epoch 27/150
# 4/4 [==============================] - 2s 441ms/step - loss: 0.1633 - precision: 0.9012 - recall: 0.7431 - val_loss: 0.0856 - val_precision: 0.7874 - val_recall: 0.9162
# Epoch 28/150
# 4/4 [==============================] - 2s 433ms/step - loss: 0.1508 - precision: 0.8865 - recall: 0.7824 - val_loss: 0.0607 - val_precision: 0.9010 - val_recall: 0.8023
# Epoch 29/150
# 4/4 [==============================] - 2s 436ms/step - loss: 0.1559 - precision: 0.8655 - recall: 0.7810 - val_loss: 0.0642 - val_precision: 0.8625 - val_recall: 0.8973
# Epoch 30/150
# 4/4 [==============================] - 2s 434ms/step - loss: 0.1441 - precision: 0.8827 - recall: 0.7967 - val_loss: 0.0621 - val_precision: 0.8907 - val_recall: 0.8656
# Epoch 31/150
# 4/4 [==============================] - 2s 439ms/step - loss: 0.1470 - precision: 0.8982 - recall: 0.7712 - val_loss: 0.0754 - val_precision: 0.8165 - val_recall: 0.9210
# Epoch 32/150
# 4/4 [==============================] - 2s 436ms/step - loss: 0.1427 - precision: 0.8838 - recall: 0.7987 - val_loss: 0.0654 - val_precision: 0.8426 - val_recall: 0.9260
# Epoch 33/150
# 4/4 [==============================] - 2s 433ms/step - loss: 0.1405 - precision: 0.8688 - recall: 0.8120 - val_loss: 0.0852 - val_precision: 0.7012 - val_recall: 0.9551
# Epoch 34/150
# 4/4 [==============================] - 2s 438ms/step - loss: 0.1378 - precision: 0.8823 - recall: 0.7978 - val_loss: 0.0849 - val_precision: 0.6909 - val_recall: 0.9520
# Epoch 35/150
# 4/4 [==============================] - 2s 442ms/step - loss: 0.1375 - precision: 0.8859 - recall: 0.7947 - val_loss: 0.1336 - val_precision: 0.5102 - val_recall: 0.9751
# Epoch 36/150
# 4/4 [==============================] - 2s 441ms/step - loss: 0.1534 - precision: 0.8784 - recall: 0.7376 - val_loss: 0.1213 - val_precision: 0.5556 - val_recall: 0.9683
# Epoch 37/150
# 4/4 [==============================] - 2s 433ms/step - loss: 0.1546 - precision: 0.8493 - recall: 0.7809 - val_loss: 0.0649 - val_precision: 0.8788 - val_recall: 0.9057
# Epoch 38/150
# 4/4 [==============================] - 2s 433ms/step - loss: 0.1449 - precision: 0.8546 - recall: 0.7942 - val_loss: 0.0617 - val_precision: 0.8697 - val_recall: 0.9157
# Epoch 39/150
# 4/4 [==============================] - 2s 444ms/step - loss: 0.1432 - precision: 0.9207 - recall: 0.7495 - val_loss: 0.0639 - val_precision: 0.8566 - val_recall: 0.9339
# Epoch 40/150
# 4/4 [==============================] - 2s 441ms/step - loss: 0.1419 - precision: 0.8742 - recall: 0.8169 - val_loss: 0.0522 - val_precision: 0.9045 - val_recall: 0.8753
# Epoch 41/150
# 4/4 [==============================] - 2s 437ms/step - loss: 0.1336 - precision: 0.9044 - recall: 0.7785 - val_loss: 0.0641 - val_precision: 0.8702 - val_recall: 0.9254
# Epoch 42/150
# 4/4 [==============================] - 2s 436ms/step - loss: 0.1326 - precision: 0.8941 - recall: 0.7996 - val_loss: 0.0545 - val_precision: 0.9010 - val_recall: 0.8945
# Epoch 43/150
# 4/4 [==============================] - 2s 441ms/step - loss: 0.1324 - precision: 0.8921 - recall: 0.8006 - val_loss: 0.0671 - val_precision: 0.8263 - val_recall: 0.9496
# Epoch 44/150
# 4/4 [==============================] - 2s 438ms/step - loss: 0.1315 - precision: 0.9036 - recall: 0.7771 - val_loss: 0.0613 - val_precision: 0.8460 - val_recall: 0.9460
# Epoch 45/150
# 4/4 [==============================] - 2s 436ms/step - loss: 0.1422 - precision: 0.8347 - recall: 0.8444 - val_loss: 0.0533 - val_precision: 0.9213 - val_recall: 0.8539
# Epoch 46/150
# 4/4 [==============================] - 2s 437ms/step - loss: 0.1838 - precision: 0.9091 - recall: 0.6263 - val_loss: 0.1687 - val_precision: 0.4738 - val_recall: 0.9811
# Epoch 47/150
# 4/4 [==============================] - 2s 439ms/step - loss: 0.1977 - precision: 0.7384 - recall: 0.7795 - val_loss: 0.0617 - val_precision: 0.9499 - val_recall: 0.7297
# Epoch 48/150
# 4/4 [==============================] - 2s 433ms/step - loss: 0.1759 - precision: 0.9446 - recall: 0.5773 - val_loss: 0.0629 - val_precision: 0.9220 - val_recall: 0.8047
# Epoch 49/150
# 4/4 [==============================] - 2s 434ms/step - loss: 0.1746 - precision: 0.7850 - recall: 0.7992 - val_loss: 0.0532 - val_precision: 0.8967 - val_recall: 0.9123
# Epoch 50/150
# 4/4 [==============================] - 2s 438ms/step - loss: 0.1533 - precision: 0.9196 - recall: 0.7286 - val_loss: 0.0499 - val_precision: 0.9370 - val_recall: 0.7772
# Epoch 51/150
# 4/4 [==============================] - 2s 441ms/step - loss: 0.1303 - precision: 0.8881 - recall: 0.7862 - val_loss: 0.0625 - val_precision: 0.8710 - val_recall: 0.9290
# Epoch 52/150
# 4/4 [==============================] - 2s 438ms/step - loss: 0.1335 - precision: 0.8809 - recall: 0.8124 - val_loss: 0.0507 - val_precision: 0.9187 - val_recall: 0.8217
# Epoch 53/150
# 4/4 [==============================] - 2s 435ms/step - loss: 0.1329 - precision: 0.9057 - recall: 0.7687 - val_loss: 0.0534 - val_precision: 0.8982 - val_recall: 0.9059
# Epoch 54/150
# 4/4 [==============================] - 2s 439ms/step - loss: 0.1270 - precision: 0.8898 - recall: 0.8076 - val_loss: 0.0517 - val_precision: 0.9101 - val_recall: 0.8899
# Epoch 55/150
# 4/4 [==============================] - 2s 446ms/step - loss: 0.1262 - precision: 0.9023 - recall: 0.7878 - val_loss: 0.0501 - val_precision: 0.9076 - val_recall: 0.9054
# Epoch 56/150
# 4/4 [==============================] - 2s 438ms/step - loss: 0.1242 - precision: 0.8852 - recall: 0.8144 - val_loss: 0.0505 - val_precision: 0.9021 - val_recall: 0.9174
# Epoch 57/150
# 4/4 [==============================] - 2s 436ms/step - loss: 0.1215 - precision: 0.8924 - recall: 0.8093 - val_loss: 0.0471 - val_precision: 0.9094 - val_recall: 0.9089
# Epoch 58/150
# 4/4 [==============================] - 2s 436ms/step - loss: 0.1199 - precision: 0.8934 - recall: 0.8062 - val_loss: 0.0486 - val_precision: 0.8966 - val_recall: 0.9264
# Epoch 59/150
# 4/4 [==============================] - 2s 444ms/step - loss: 0.1183 - precision: 0.8844 - recall: 0.8221 - val_loss: 0.0483 - val_precision: 0.8962 - val_recall: 0.9294
# Epoch 60/150
# 4/4 [==============================] - 2s 435ms/step - loss: 0.1188 - precision: 0.8992 - recall: 0.8036 - val_loss: 0.0513 - val_precision: 0.8911 - val_recall: 0.9347
# Epoch 61/150
# 4/4 [==============================] - 2s 434ms/step - loss: 0.1176 - precision: 0.8887 - recall: 0.8210 - val_loss: 0.0485 - val_precision: 0.8782 - val_recall: 0.9440
# Epoch 62/150
# 4/4 [==============================] - 2s 439ms/step - loss: 0.1143 - precision: 0.8739 - recall: 0.8374 - val_loss: 0.0485 - val_precision: 0.8831 - val_recall: 0.9384
# Epoch 63/150
# 4/4 [==============================] - 2s 449ms/step - loss: 0.1128 - precision: 0.8919 - recall: 0.8171 - val_loss: 0.0439 - val_precision: 0.8914 - val_recall: 0.9433
# Epoch 64/150
# 4/4 [==============================] - 2s 438ms/step - loss: 0.1090 - precision: 0.9002 - recall: 0.8139 - val_loss: 0.0485 - val_precision: 0.9050 - val_recall: 0.9315
# Epoch 65/150
# 4/4 [==============================] - 2s 440ms/step - loss: 0.1149 - precision: 0.9011 - recall: 0.7991 - val_loss: 0.0608 - val_precision: 0.8135 - val_recall: 0.9623
# Epoch 66/150
# 4/4 [==============================] - 2s 438ms/step - loss: 0.1097 - precision: 0.8987 - recall: 0.8149 - val_loss: 0.0608 - val_precision: 0.8179 - val_recall: 0.9605
# Epoch 67/150
# 4/4 [==============================] - 2s 443ms/step - loss: 0.1035 - precision: 0.9017 - recall: 0.8224 - val_loss: 0.0472 - val_precision: 0.8565 - val_recall: 0.9582
# Epoch 68/150
# 4/4 [==============================] - 2s 435ms/step - loss: 0.1048 - precision: 0.8901 - recall: 0.8343 - val_loss: 0.0748 - val_precision: 0.7086 - val_recall: 0.9740
# Epoch 69/150
# 4/4 [==============================] - 2s 439ms/step - loss: 0.0978 - precision: 0.9046 - recall: 0.8167 - val_loss: 0.1119 - val_precision: 0.5815 - val_recall: 0.9786
# Epoch 70/150
# 4/4 [==============================] - 2s 436ms/step - loss: 0.0965 - precision: 0.8938 - recall: 0.8305 - val_loss: 0.0786 - val_precision: 0.6758 - val_recall: 0.9622
# Epoch 71/150
# 4/4 [==============================] - 2s 449ms/step - loss: 0.1019 - precision: 0.8623 - recall: 0.8553 - val_loss: 0.0565 - val_precision: 0.8184 - val_recall: 0.9554
# Epoch 72/150
# 4/4 [==============================] - 2s 433ms/step - loss: 0.0931 - precision: 0.9177 - recall: 0.7956 - val_loss: 0.0938 - val_precision: 0.6194 - val_recall: 0.9748
# Epoch 73/150
# 4/4 [==============================] - 2s 437ms/step - loss: 0.0952 - precision: 0.8724 - recall: 0.8632 - val_loss: 0.0738 - val_precision: 0.7193 - val_recall: 0.9726
# Epoch 74/150
# 4/4 [==============================] - 2s 437ms/step - loss: 0.0863 - precision: 0.9063 - recall: 0.8338 - val_loss: 0.1236 - val_precision: 0.5551 - val_recall: 0.9812
# Epoch 75/150
# 4/4 [==============================] - 2s 443ms/step - loss: 0.0844 - precision: 0.8823 - recall: 0.8732 - val_loss: 0.0702 - val_precision: 0.7232 - val_recall: 0.9704
# Epoch 76/150
# 4/4 [==============================] - 2s 441ms/step - loss: 0.0839 - precision: 0.8911 - recall: 0.8499 - val_loss: 0.0750 - val_precision: 0.6914 - val_recall: 0.9755
# Epoch 77/150
# 4/4 [==============================] - 2s 442ms/step - loss: 0.0830 - precision: 0.8874 - recall: 0.8672 - val_loss: 0.0856 - val_precision: 0.6807 - val_recall: 0.9765
# Epoch 78/150
# 4/4 [==============================] - 2s 438ms/step - loss: 0.0861 - precision: 0.9057 - recall: 0.8252 - val_loss: 0.1627 - val_precision: 0.4986 - val_recall: 0.9856
# Epoch 79/150
# 4/4 [==============================] - 2s 444ms/step - loss: 0.0939 - precision: 0.8566 - recall: 0.8779 - val_loss: 0.0534 - val_precision: 0.8456 - val_recall: 0.9730
# Epoch 80/150
# 4/4 [==============================] - 2s 438ms/step - loss: 0.0877 - precision: 0.8803 - recall: 0.8691 - val_loss: 0.0942 - val_precision: 0.6096 - val_recall: 0.9759
# Epoch 81/150
# 4/4 [==============================] - 2s 437ms/step - loss: 0.1138 - precision: 0.8930 - recall: 0.8450 - val_loss: 0.1530 - val_precision: 0.4915 - val_recall: 0.9815
# Epoch 82/150
# 4/4 [==============================] - 2s 434ms/step - loss: 0.1304 - precision: 0.8654 - recall: 0.7834 - val_loss: 0.1848 - val_precision: 0.4345 - val_recall: 0.9854
# Epoch 83/150
# 4/4 [==============================] - 2s 445ms/step - loss: 0.1801 - precision: 0.6727 - recall: 0.8858 - val_loss: 0.0581 - val_precision: 0.9531 - val_recall: 0.7387
# Epoch 84/150
# 4/4 [==============================] - 2s 434ms/step - loss: 0.1410 - precision: 0.9473 - recall: 0.6191 - val_loss: 0.0548 - val_precision: 0.9485 - val_recall: 0.7634
# Epoch 85/150
# 4/4 [==============================] - 2s 433ms/step - loss: 0.1142 - precision: 0.8899 - recall: 0.7981 - val_loss: 0.0493 - val_precision: 0.8787 - val_recall: 0.9451
# Epoch 86/150
# 4/4 [==============================] - 2s 438ms/step - loss: 0.1063 - precision: 0.8817 - recall: 0.8226 - val_loss: 0.0525 - val_precision: 0.9441 - val_recall: 0.7858
# Epoch 87/150
# 4/4 [==============================] - 2s 444ms/step - loss: 0.0951 - precision: 0.9224 - recall: 0.7785 - val_loss: 0.0486 - val_precision: 0.9021 - val_recall: 0.8974
# Epoch 88/150
# 4/4 [==============================] - 2s 435ms/step - loss: 0.0919 - precision: 0.8810 - recall: 0.8355 - val_loss: 0.0480 - val_precision: 0.8582 - val_recall: 0.9389
# Epoch 89/150
# 4/4 [==============================] - 2s 438ms/step - loss: 0.0908 - precision: 0.8785 - recall: 0.8508 - val_loss: 0.0446 - val_precision: 0.9287 - val_recall: 0.8684
# Epoch 90/150
# 4/4 [==============================] - 2s 440ms/step - loss: 0.0861 - precision: 0.8960 - recall: 0.8455 - val_loss: 0.0371 - val_precision: 0.9115 - val_recall: 0.9297
# Epoch 91/150
# 4/4 [==============================] - 2s 439ms/step - loss: 0.0819 - precision: 0.8717 - recall: 0.8895 - val_loss: 0.0350 - val_precision: 0.9097 - val_recall: 0.9310
# Epoch 92/150
# 4/4 [==============================] - 2s 434ms/step - loss: 0.0844 - precision: 0.8920 - recall: 0.8601 - val_loss: 0.0732 - val_precision: 0.6894 - val_recall: 0.9327
# Epoch 93/150
# 4/4 [==============================] - 2s 435ms/step - loss: 0.0953 - precision: 0.8484 - recall: 0.8684 - val_loss: 0.0374 - val_precision: 0.9049 - val_recall: 0.9506
# Epoch 94/150
# 4/4 [==============================] - 2s 437ms/step - loss: 0.0819 - precision: 0.8855 - recall: 0.8697 - val_loss: 0.0451 - val_precision: 0.9040 - val_recall: 0.9260
# Epoch 95/150
# 4/4 [==============================] - 2s 442ms/step - loss: 0.0815 - precision: 0.8879 - recall: 0.8622 - val_loss: 0.0325 - val_precision: 0.9254 - val_recall: 0.9384
# Epoch 96/150
# 4/4 [==============================] - 2s 436ms/step - loss: 0.0814 - precision: 0.8934 - recall: 0.8661 - val_loss: 0.0316 - val_precision: 0.9279 - val_recall: 0.9393
# Epoch 97/150
# 4/4 [==============================] - 2s 440ms/step - loss: 0.0755 - precision: 0.8954 - recall: 0.8855 - val_loss: 0.0374 - val_precision: 0.9105 - val_recall: 0.9491
# Epoch 98/150
# 4/4 [==============================] - 2s 443ms/step - loss: 0.0757 - precision: 0.8844 - recall: 0.9022 - val_loss: 0.0341 - val_precision: 0.9051 - val_recall: 0.9558
# Epoch 99/150
# 4/4 [==============================] - 2s 438ms/step - loss: 0.0802 - precision: 0.9067 - recall: 0.8531 - val_loss: 0.0391 - val_precision: 0.8966 - val_recall: 0.9567
# Epoch 100/150
# 4/4 [==============================] - 2s 439ms/step - loss: 0.0751 - precision: 0.8703 - recall: 0.9204 - val_loss: 0.0312 - val_precision: 0.9192 - val_recall: 0.9505
# Epoch 101/150
# 4/4 [==============================] - 2s 435ms/step - loss: 0.0731 - precision: 0.9015 - recall: 0.8845 - val_loss: 0.0318 - val_precision: 0.9110 - val_recall: 0.9545
# Epoch 102/150
# 4/4 [==============================] - 2s 434ms/step - loss: 0.0694 - precision: 0.9044 - recall: 0.8984 - val_loss: 0.0340 - val_precision: 0.9002 - val_recall: 0.9553
# Epoch 103/150
# 4/4 [==============================] - 2s 451ms/step - loss: 0.0654 - precision: 0.8944 - recall: 0.9259 - val_loss: 0.0293 - val_precision: 0.9203 - val_recall: 0.9492
# Epoch 104/150
# 4/4 [==============================] - 2s 441ms/step - loss: 0.0681 - precision: 0.9095 - recall: 0.8933 - val_loss: 0.0324 - val_precision: 0.8873 - val_recall: 0.9662
# Epoch 105/150
# 4/4 [==============================] - 2s 437ms/step - loss: 0.0607 - precision: 0.8936 - recall: 0.9361 - val_loss: 0.0294 - val_precision: 0.9104 - val_recall: 0.9571
# Epoch 106/150
# 4/4 [==============================] - 2s 436ms/step - loss: 0.0627 - precision: 0.9143 - recall: 0.9034 - val_loss: 0.0397 - val_precision: 0.8428 - val_recall: 0.9633
# Epoch 107/150
# 4/4 [==============================] - 2s 437ms/step - loss: 0.0632 - precision: 0.8903 - recall: 0.9329 - val_loss: 0.0284 - val_precision: 0.9213 - val_recall: 0.9504
# Epoch 108/150
# 4/4 [==============================] - 2s 434ms/step - loss: 0.0577 - precision: 0.9186 - recall: 0.9163 - val_loss: 0.0294 - val_precision: 0.9028 - val_recall: 0.9648
# Epoch 109/150
# 4/4 [==============================] - 2s 441ms/step - loss: 0.0578 - precision: 0.9014 - recall: 0.9393 - val_loss: 0.0267 - val_precision: 0.9219 - val_recall: 0.9552
# Epoch 110/150
# 4/4 [==============================] - 2s 434ms/step - loss: 0.0605 - precision: 0.9345 - recall: 0.8860 - val_loss: 0.0355 - val_precision: 0.8581 - val_recall: 0.9737
# Epoch 111/150
# 4/4 [==============================] - 2s 442ms/step - loss: 0.0586 - precision: 0.8762 - recall: 0.9611 - val_loss: 0.0315 - val_precision: 0.8920 - val_recall: 0.9599
# Epoch 112/150
# 4/4 [==============================] - 2s 438ms/step - loss: 0.0539 - precision: 0.9271 - recall: 0.9140 - val_loss: 0.0314 - val_precision: 0.8982 - val_recall: 0.9575
# Epoch 113/150
# 4/4 [==============================] - 2s 434ms/step - loss: 0.0507 - precision: 0.9169 - recall: 0.9385 - val_loss: 0.0340 - val_precision: 0.8788 - val_recall: 0.9677
# Epoch 114/150
# 4/4 [==============================] - 2s 444ms/step - loss: 0.0490 - precision: 0.9161 - recall: 0.9425 - val_loss: 0.0323 - val_precision: 0.8921 - val_recall: 0.9659
# Epoch 115/150
# 4/4 [==============================] - 2s 437ms/step - loss: 0.0502 - precision: 0.9258 - recall: 0.9250 - val_loss: 0.0325 - val_precision: 0.8909 - val_recall: 0.9604
# Epoch 116/150
# 4/4 [==============================] - 2s 440ms/step - loss: 0.0518 - precision: 0.9164 - recall: 0.9355 - val_loss: 0.0278 - val_precision: 0.9177 - val_recall: 0.9595
# Epoch 117/150
# 4/4 [==============================] - 2s 433ms/step - loss: 0.0503 - precision: 0.9126 - recall: 0.9416 - val_loss: 0.0315 - val_precision: 0.8846 - val_recall: 0.9727
# Epoch 118/150
# 4/4 [==============================] - 2s 436ms/step - loss: 0.0460 - precision: 0.9149 - recall: 0.9478 - val_loss: 0.0266 - val_precision: 0.9244 - val_recall: 0.9516
# Epoch 119/150
# 4/4 [==============================] - 2s 438ms/step - loss: 0.0448 - precision: 0.9355 - recall: 0.9256 - val_loss: 0.0513 - val_precision: 0.8122 - val_recall: 0.9755
# Epoch 120/150
# 4/4 [==============================] - 2s 448ms/step - loss: 0.0427 - precision: 0.9196 - recall: 0.9557 - val_loss: 0.0291 - val_precision: 0.9158 - val_recall: 0.9499
# Epoch 121/150
# 4/4 [==============================] - 2s 435ms/step - loss: 0.0424 - precision: 0.9564 - recall: 0.9163 - val_loss: 0.0380 - val_precision: 0.8624 - val_recall: 0.9698
# Epoch 122/150
# 4/4 [==============================] - 2s 435ms/step - loss: 0.0404 - precision: 0.9259 - recall: 0.9518 - val_loss: 0.0368 - val_precision: 0.8799 - val_recall: 0.9582
# Epoch 123/150
# 4/4 [==============================] - 2s 445ms/step - loss: 0.0388 - precision: 0.9464 - recall: 0.9376 - val_loss: 0.0316 - val_precision: 0.9080 - val_recall: 0.9522
# Epoch 124/150
# 4/4 [==============================] - 2s 435ms/step - loss: 0.0366 - precision: 0.9476 - recall: 0.9457 - val_loss: 0.0413 - val_precision: 0.8570 - val_recall: 0.9776
# Epoch 125/150
# 4/4 [==============================] - 2s 433ms/step - loss: 0.0432 - precision: 0.9413 - recall: 0.9365 - val_loss: 0.0310 - val_precision: 0.9198 - val_recall: 0.9413
# Epoch 126/150
# 4/4 [==============================] - 2s 438ms/step - loss: 0.0362 - precision: 0.9411 - recall: 0.9553 - val_loss: 0.0342 - val_precision: 0.8858 - val_recall: 0.9607
# Epoch 127/150
# 4/4 [==============================] - 2s 438ms/step - loss: 0.0339 - precision: 0.9550 - recall: 0.9435 - val_loss: 0.0317 - val_precision: 0.8979 - val_recall: 0.9551
# Epoch 128/150
# 4/4 [==============================] - 2s 433ms/step - loss: 0.0326 - precision: 0.9526 - recall: 0.9507 - val_loss: 0.0372 - val_precision: 0.8791 - val_recall: 0.9630
# Epoch 129/150
# 4/4 [==============================] - 2s 432ms/step - loss: 0.0307 - precision: 0.9516 - recall: 0.9573 - val_loss: 0.0313 - val_precision: 0.9157 - val_recall: 0.9435
# Epoch 130/150
# 4/4 [==============================] - 2s 435ms/step - loss: 0.0293 - precision: 0.9615 - recall: 0.9505 - val_loss: 0.0417 - val_precision: 0.8677 - val_recall: 0.9619
# Epoch 131/150
# 4/4 [==============================] - 2s 442ms/step - loss: 0.0315 - precision: 0.9500 - recall: 0.9572 - val_loss: 0.0321 - val_precision: 0.9029 - val_recall: 0.9598
# Epoch 132/150
# 4/4 [==============================] - 2s 434ms/step - loss: 0.0298 - precision: 0.9613 - recall: 0.9503 - val_loss: 0.0421 - val_precision: 0.8550 - val_recall: 0.9758
# Epoch 133/150
# 4/4 [==============================] - 2s 434ms/step - loss: 0.0299 - precision: 0.9585 - recall: 0.9536 - val_loss: 0.0320 - val_precision: 0.9079 - val_recall: 0.9636
# Epoch 134/150
# 4/4 [==============================] - 2s 436ms/step - loss: 0.0266 - precision: 0.9621 - recall: 0.9593 - val_loss: 0.0457 - val_precision: 0.8577 - val_recall: 0.9743
# Epoch 135/150
# 4/4 [==============================] - 2s 441ms/step - loss: 0.0254 - precision: 0.9660 - recall: 0.9584 - val_loss: 0.0319 - val_precision: 0.9106 - val_recall: 0.9587
# Epoch 136/150
# 4/4 [==============================] - 2s 434ms/step - loss: 0.0253 - precision: 0.9639 - recall: 0.9599 - val_loss: 0.0378 - val_precision: 0.8823 - val_recall: 0.9759
# Epoch 137/150
# 4/4 [==============================] - 2s 437ms/step - loss: 0.0251 - precision: 0.9583 - recall: 0.9683 - val_loss: 0.0310 - val_precision: 0.9156 - val_recall: 0.9631
# Epoch 138/150
# 4/4 [==============================] - 2s 435ms/step - loss: 0.0248 - precision: 0.9726 - recall: 0.9529 - val_loss: 0.0373 - val_precision: 0.8956 - val_recall: 0.9670
# Epoch 139/150
# 4/4 [==============================] - 2s 439ms/step - loss: 0.0237 - precision: 0.9615 - recall: 0.9684 - val_loss: 0.0356 - val_precision: 0.9091 - val_recall: 0.9494
# Epoch 140/150
# 4/4 [==============================] - 2s 434ms/step - loss: 0.0231 - precision: 0.9699 - recall: 0.9627 - val_loss: 0.0405 - val_precision: 0.8783 - val_recall: 0.9649
# Epoch 141/150
# 4/4 [==============================] - 2s 436ms/step - loss: 0.0235 - precision: 0.9629 - recall: 0.9683 - val_loss: 0.0315 - val_precision: 0.9238 - val_recall: 0.9512
# Epoch 142/150
# 4/4 [==============================] - 2s 434ms/step - loss: 0.0239 - precision: 0.9741 - recall: 0.9563 - val_loss: 0.0464 - val_precision: 0.8519 - val_recall: 0.9726
# Epoch 143/150
# 4/4 [==============================] - 2s 436ms/step - loss: 0.0243 - precision: 0.9584 - recall: 0.9705 - val_loss: 0.0361 - val_precision: 0.8904 - val_recall: 0.9565
# Epoch 144/150
# 4/4 [==============================] - 2s 436ms/step - loss: 0.0229 - precision: 0.9724 - recall: 0.9591 - val_loss: 0.0387 - val_precision: 0.8871 - val_recall: 0.9671
# Epoch 145/150
# 4/4 [==============================] - 2s 436ms/step - loss: 0.0220 - precision: 0.9703 - recall: 0.9657 - val_loss: 0.0452 - val_precision: 0.8660 - val_recall: 0.9713
# Epoch 146/150
# 4/4 [==============================] - 2s 436ms/step - loss: 0.0213 - precision: 0.9680 - recall: 0.9693 - val_loss: 0.0385 - val_precision: 0.8886 - val_recall: 0.9635
# Epoch 147/150
# 4/4 [==============================] - 2s 447ms/step - loss: 0.0217 - precision: 0.9704 - recall: 0.9645 - val_loss: 0.0408 - val_precision: 0.8806 - val_recall: 0.9671
# Epoch 148/150
# 4/4 [==============================] - 2s 434ms/step - loss: 0.0213 - precision: 0.9664 - recall: 0.9708 - val_loss: 0.0407 - val_precision: 0.8830 - val_recall: 0.9679
# Epoch 149/150
# 4/4 [==============================] - 2s 435ms/step - loss: 0.0198 - precision: 0.9748 - recall: 0.9659 - val_loss: 0.0372 - val_precision: 0.8873 - val_recall: 0.9693
# Epoch 150/150
# 4/4 [==============================] - 2s 434ms/step - loss: 0.0199 - precision: 0.9687 - recall: 0.9729 - val_loss: 0.0397 - val_precision: 0.8843 - val_recall: 0.9672

# %%
model.evaluate(X_train,Y_train)
# Out:
# 1/1 [==============================] - 8s 8s/step - loss: 0.0450 - precision: 0.9310 - recall: 0.9580
# [0.04503956064581871, 0.9309540390968323, 0.9579609036445618]

# %%
print(history.history.keys())
plt.figure(figsize=(10,10))
plt.subplot(331)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')

plt.subplot(332)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')


plt.subplot(333)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
# Out:
# dict_keys(['loss', 'precision', 'recall', 'val_loss', 'val_precision', 'val_recall'])

# %%
n = np.random.randint(0,15)
X_test = X_train[n]
Y_test = Y_train[n] 

plt.figure(figsize=(15,15))
plt.subplot(441)
plt.imshow(X_test)
plt.title('Testing RGB')

plt.subplot(442)
plt.imshow(Y_test)
plt.title('Testing Mask')
print(X_test.shape)
print(Y_test.shape)


testing = np.expand_dims(X_test,axis=0)
pred = model.predict(testing,verbose=1)
preds = np.argmax(pred,axis=-1)

plt.figure(figsize=(15,15))
plt.subplot(444)
plt.imshow(np.squeeze(pred>=0.95))
plt.title('Predictions')
plt.subplot(443)
plt.imshow(X_test)
plt.title('Testing RGB')
# Out:
# (512, 512, 3)
# (512, 512)
# 1/1 [==============================] - 1s 1s/step
# Text(0.5, 1.0, 'Testing RGB')

# %%
model.save('/content/Toby_unet_building_detection_epoch150_df.h5')
