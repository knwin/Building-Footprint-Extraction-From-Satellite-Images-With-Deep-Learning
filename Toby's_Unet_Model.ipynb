# %% [markdown]
# <a href="https://colab.research.google.com/github/Aye-Nyein-Thaw/Building-Footprint-Extraction-Practical-Project/blob/toby/Toby's_Unet_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import os
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

# %%
os.chdir('/content/drive/MyDrive/Unet_test/2.Image part')

# %%
ls
# Out:
# 'Binary Mask'/   img.png  'Processed Image'/

# %%
train_path = 'Processed Image/'
test_path = 'Binary Mask/'

img_height =512 
img_width = 512
img_channels = 3

train_ids = sorted(next(os.walk(train_path)) [2])
print(train_ids[0])
test_ids = sorted(next(os.walk(test_path)) [2])
print(test_ids[0])
# Out:
# processed_image+final_00001_a0.png
# mask_00001_a0.png

# %%
sorted(test_ids)
# Out:
# ['mask_00001_a0.png',
#  'mask_00002_a0.png',
#  'mask_00003_a0.png',
#  'mask_00004_a0.png',
#  'mask_00005_a0.png',
#  'mask_00006_a0.png',
#  'mask_00007_a0.png',
#  'mask_00008_a0.png',
#  'mask_00009_a0.png',
#  'mask_00010_a0.png',
#  'mask_00011_a0.png',
#  'mask_00012_a0.png',
#  'mask_00013_a0.png',
#  'mask_00014_a0.png',
#  'mask_00015_a0.png',
#  'mask_00016_a0.png',
#  'mask_00017_a0.png',
#  'mask_00018_a0.png',
#  'mask_00019_a0.png',
#  'mask_00020_a0.png']

# %%
train_ids
# Out:
# ['processed_image+final_00001_a0.png',
#  'processed_image+final_00002_a0.png',
#  'processed_image+final_00003_a0.png',
#  'processed_image+final_00004_a0.png',
#  'processed_image+final_00005_a0.png',
#  'processed_image+final_00006_a0.png',
#  'processed_image+final_00007_a0.png',
#  'processed_image+final_00008_a0.png',
#  'processed_image+final_00009_a0.png',
#  'processed_image+final_00010_a0.png',
#  'processed_image+final_00011_a0.png',
#  'processed_image+final_00012_a0.png',
#  'processed_image+final_00013_a0.png',
#  'processed_image+final_00014_a0.png',
#  'processed_image+final_00015_a0.png',
#  'processed_image+final_00016_a0.png',
#  'processed_image+final_00017_a0.png',
#  'processed_image+final_00018_a0.png',
#  'processed_image+final_00019_a0.png',
#  'processed_image+final_00020_a0.png']

# %%
print(len(train_ids))
print(len(test_ids))
# Out:
# 20
# 20

# %%
X_train = np.zeros((len(train_ids),img_height, img_width, img_channels ), dtype=np.uint8)
Y_train = np.zeros((len(test_ids),img_height,img_width),dtype=np.bool)

# %%
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = train_path + id_
    print(path)
    img = Image.open(path)
    X_train[n]=img
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Processed Image/processed_image+final_00001_a0.png
#   5%|▌         | 1/20 [00:00<00:11,  1.59it/s]
# Processed Image/processed_image+final_00002_a0.png
#  10%|█         | 2/20 [00:01<00:11,  1.51it/s]
# Processed Image/processed_image+final_00003_a0.png
#  15%|█▌        | 3/20 [00:02<00:16,  1.03it/s]
# Processed Image/processed_image+final_00004_a0.png
#  20%|██        | 4/20 [00:03<00:15,  1.05it/s]
# Processed Image/processed_image+final_00005_a0.png
#  25%|██▌       | 5/20 [00:04<00:13,  1.08it/s]
# Processed Image/processed_image+final_00006_a0.png
#  30%|███       | 6/20 [00:05<00:12,  1.13it/s]
# Processed Image/processed_image+final_00007_a0.png
#  35%|███▌      | 7/20 [00:05<00:10,  1.30it/s]
# Processed Image/processed_image+final_00008_a0.png
#  40%|████      | 8/20 [00:06<00:08,  1.36it/s]
# Processed Image/processed_image+final_00009_a0.png
#  45%|████▌     | 9/20 [00:07<00:07,  1.43it/s]
# Processed Image/processed_image+final_00010_a0.png
#  50%|█████     | 10/20 [00:07<00:06,  1.53it/s]
# Processed Image/processed_image+final_00011_a0.png
#  55%|█████▌    | 11/20 [00:08<00:05,  1.55it/s]
# Processed Image/processed_image+final_00012_a0.png
#  60%|██████    | 12/20 [00:08<00:05,  1.54it/s]
# Processed Image/processed_image+final_00013_a0.png
#  65%|██████▌   | 13/20 [00:09<00:04,  1.65it/s]
# Processed Image/processed_image+final_00014_a0.png
#  70%|███████   | 14/20 [00:10<00:03,  1.61it/s]
# Processed Image/processed_image+final_00015_a0.png
#  75%|███████▌  | 15/20 [00:10<00:03,  1.60it/s]
# Processed Image/processed_image+final_00016_a0.png
#  80%|████████  | 16/20 [00:11<00:02,  1.60it/s]
# Processed Image/processed_image+final_00017_a0.png
#  85%|████████▌ | 17/20 [00:11<00:01,  1.62it/s]
# Processed Image/processed_image+final_00018_a0.png
#  90%|█████████ | 18/20 [00:12<00:01,  1.63it/s]
# Processed Image/processed_image+final_00019_a0.png
#  95%|█████████▌| 19/20 [00:13<00:00,  1.74it/s]
# Processed Image/processed_image+final_00020_a0.png
# 100%|██████████| 20/20 [00:13<00:00,  1.48it/s]

# %%
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path_test = test_path + id_
    print(path_test)
    mask = Image.open(path_test)
    Y_train[n]=mask
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Binary Mask/mask_00001_a0.png
#   5%|▌         | 1/20 [00:00<00:09,  1.90it/s]
# Binary Mask/mask_00002_a0.png
#  10%|█         | 2/20 [00:01<00:08,  2.00it/s]
# Binary Mask/mask_00003_a0.png
#  15%|█▌        | 3/20 [00:01<00:08,  1.92it/s]
# Binary Mask/mask_00004_a0.png
#  20%|██        | 4/20 [00:01<00:06,  2.33it/s]
# Binary Mask/mask_00005_a0.png
#  25%|██▌       | 5/20 [00:02<00:07,  2.01it/s]
# Binary Mask/mask_00006_a0.png
#  30%|███       | 6/20 [00:03<00:07,  1.90it/s]
# Binary Mask/mask_00007_a0.png
#  35%|███▌      | 7/20 [00:03<00:06,  2.01it/s]
# Binary Mask/mask_00008_a0.png
#  40%|████      | 8/20 [00:03<00:05,  2.07it/s]
# Binary Mask/mask_00009_a0.png
#  45%|████▌     | 9/20 [00:04<00:05,  1.87it/s]
# Binary Mask/mask_00010_a0.png
#  50%|█████     | 10/20 [00:05<00:05,  1.97it/s]
# Binary Mask/mask_00011_a0.png
#  55%|█████▌    | 11/20 [00:05<00:04,  1.83it/s]
# Binary Mask/mask_00012_a0.png
#  60%|██████    | 12/20 [00:06<00:04,  1.71it/s]
# Binary Mask/mask_00013_a0.png
#  65%|██████▌   | 13/20 [00:06<00:03,  1.80it/s]
# Binary Mask/mask_00014_a0.png
#  70%|███████   | 14/20 [00:07<00:03,  1.91it/s]
# Binary Mask/mask_00015_a0.png
#  75%|███████▌  | 15/20 [00:07<00:02,  1.87it/s]
# Binary Mask/mask_00016_a0.png
#  80%|████████  | 16/20 [00:08<00:01,  2.01it/s]
# Binary Mask/mask_00017_a0.png
#  85%|████████▌ | 17/20 [00:08<00:01,  1.94it/s]
# Binary Mask/mask_00018_a0.png
#  90%|█████████ | 18/20 [00:09<00:01,  1.87it/s]
# Binary Mask/mask_00019_a0.png
#  95%|█████████▌| 19/20 [00:09<00:00,  2.02it/s]
# Binary Mask/mask_00020_a0.png
# 100%|██████████| 20/20 [00:10<00:00,  1.93it/s]

# %%
def plotting (x ,y):
  n = np.random.randint(0,20)
  plt.subplot(121)
  plt.imshow(x[n])
  plt.subplot(122)
  plt.imshow(y[n])

plotting(X_train,Y_train)

# %%
#X_train_new = X_train/255
#Y_train_new = Y_train/255
#plotting(X_train_new,Y_t  rain_new)

#img_size = 512
#num_classes =2 

plotting(X_train,Y_train)

print(X_train[n].shape)
print(Y_train[n].shape)
# Out:
# (512, 512, 3)
# (512, 512)

# %%
#Build the model
IMG_HEIGHT = 512
IMG_WIDTH = 512
IMG_CHANNELS = 3
inputs = tf.keras.layers.Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = tf.keras.layers.Lambda(lambda x: x / 255)(inputs)

#Contraction path
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)
 
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
c3 = tf.keras.layers.Dropout(0.2)(c3)
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)
 
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
c4 = tf.keras.layers.Dropout(0.2)(c4)
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c4)
 
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
c5 = tf.keras.layers.Dropout(0.3)(c5)
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

#Expansive path 
u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = tf.keras.layers.concatenate([u6, c4])
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
c6 = tf.keras.layers.Dropout(0.2)(c6)
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
 
u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
u7 = tf.keras.layers.concatenate([u7, c3])
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
c7 = tf.keras.layers.Dropout(0.2)(c7)
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)
 
u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
u8 = tf.keras.layers.concatenate([u8, c2])
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
c8 = tf.keras.layers.Dropout(0.1)(c8)
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
 
u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
c9 = tf.keras.layers.Dropout(0.1)(c9)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
 
outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)
 
model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy',tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
#model.summary()

# %%
history = model.fit(X_train,Y_train,epochs=150,verbose = 1, batch_size=4,validation_split=0.2)
# Out:
# Epoch 1/150
# 4/4 [==============================] - 5s 671ms/step - loss: 0.6597 - accuracy: 0.7781 - precision_2: 0.1126 - recall_2: 0.0959 - val_loss: 0.6117 - val_accuracy: 0.9269 - val_precision_2: 0.0612 - val_recall_2: 3.9138e-05
# Epoch 2/150
# 4/4 [==============================] - 2s 444ms/step - loss: 0.4854 - accuracy: 0.8661 - precision_2: 0.1251 - recall_2: 2.7110e-04 - val_loss: 0.5313 - val_accuracy: 0.9269 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 3/150
# 4/4 [==============================] - 2s 441ms/step - loss: 0.4348 - accuracy: 0.8663 - precision_2: 0.1176 - recall_2: 3.5671e-06 - val_loss: 0.5062 - val_accuracy: 0.9269 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 4/150
# 4/4 [==============================] - 2s 442ms/step - loss: 0.4307 - accuracy: 0.8663 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.4939 - val_accuracy: 0.9269 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 5/150
# 4/4 [==============================] - 2s 438ms/step - loss: 0.4159 - accuracy: 0.8663 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.4710 - val_accuracy: 0.9269 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 6/150
# 4/4 [==============================] - 2s 443ms/step - loss: 0.4093 - accuracy: 0.8663 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.4113 - val_accuracy: 0.9269 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 7/150
# 4/4 [==============================] - 2s 445ms/step - loss: 0.3899 - accuracy: 0.8663 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.3831 - val_accuracy: 0.9269 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 8/150
# 4/4 [==============================] - 2s 447ms/step - loss: 0.3636 - accuracy: 0.8663 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.2552 - val_accuracy: 0.9269 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 9/150
# 4/4 [==============================] - 2s 443ms/step - loss: 0.3154 - accuracy: 0.8663 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1909 - val_accuracy: 0.9269 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 10/150
# 4/4 [==============================] - 2s 441ms/step - loss: 0.2673 - accuracy: 0.8663 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 0.1304 - val_accuracy: 0.9269 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 11/150
# 4/4 [==============================] - 2s 442ms/step - loss: 0.2834 - accuracy: 0.8663 - precision_2: 1.0000 - recall_2: 1.6052e-05 - val_loss: 0.1142 - val_accuracy: 0.9269 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 12/150
# 4/4 [==============================] - 2s 447ms/step - loss: 0.2728 - accuracy: 0.8663 - precision_2: 0.7692 - recall_2: 1.0701e-04 - val_loss: 0.1960 - val_accuracy: 0.9269 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 13/150
# 4/4 [==============================] - 2s 440ms/step - loss: 0.2925 - accuracy: 0.8664 - precision_2: 0.8397 - recall_2: 7.0985e-04 - val_loss: 0.1123 - val_accuracy: 0.9269 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 14/150
# 4/4 [==============================] - 2s 448ms/step - loss: 0.2750 - accuracy: 0.8663 - precision_2: 0.8429 - recall_2: 1.0523e-04 - val_loss: 0.1545 - val_accuracy: 0.9269 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 15/150
# 4/4 [==============================] - 2s 442ms/step - loss: 0.2563 - accuracy: 0.8664 - precision_2: 0.8715 - recall_2: 7.7405e-04 - val_loss: 0.1639 - val_accuracy: 0.9269 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 16/150
# 4/4 [==============================] - 2s 444ms/step - loss: 0.2281 - accuracy: 0.8664 - precision_2: 0.9415 - recall_2: 5.4576e-04 - val_loss: 0.1021 - val_accuracy: 0.9269 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 17/150
# 4/4 [==============================] - 2s 447ms/step - loss: 0.2315 - accuracy: 0.8667 - precision_2: 0.8602 - recall_2: 0.0034 - val_loss: 0.1439 - val_accuracy: 0.9269 - val_precision_2: 0.1905 - val_recall_2: 5.2185e-05
# Epoch 18/150
# 4/4 [==============================] - 2s 443ms/step - loss: 0.2119 - accuracy: 0.8693 - precision_2: 0.9112 - recall_2: 0.0247 - val_loss: 0.1000 - val_accuracy: 0.9269 - val_precision_2: 0.4767 - val_recall_2: 5.3489e-04
# Epoch 19/150
# 4/4 [==============================] - 2s 447ms/step - loss: 0.2140 - accuracy: 0.8785 - precision_2: 0.9633 - recall_2: 0.0943 - val_loss: 0.1230 - val_accuracy: 0.9491 - val_precision_2: 0.6846 - val_recall_2: 0.5642
# Epoch 20/150
# 4/4 [==============================] - 2s 446ms/step - loss: 0.2238 - accuracy: 0.9155 - precision_2: 0.8707 - recall_2: 0.4321 - val_loss: 0.1126 - val_accuracy: 0.9654 - val_precision_2: 0.7761 - val_recall_2: 0.7407
# Epoch 21/150
# 4/4 [==============================] - 2s 447ms/step - loss: 0.2120 - accuracy: 0.9152 - precision_2: 0.9439 - recall_2: 0.3886 - val_loss: 0.0999 - val_accuracy: 0.9743 - val_precision_2: 0.9066 - val_recall_2: 0.7225
# Epoch 22/150
# 4/4 [==============================] - 2s 444ms/step - loss: 0.2028 - accuracy: 0.9381 - precision_2: 0.8974 - recall_2: 0.6060 - val_loss: 0.1300 - val_accuracy: 0.9434 - val_precision_2: 0.5768 - val_recall_2: 0.8473
# Epoch 23/150
# 4/4 [==============================] - 2s 441ms/step - loss: 0.1951 - accuracy: 0.9386 - precision_2: 0.9249 - recall_2: 0.5886 - val_loss: 0.0887 - val_accuracy: 0.9758 - val_precision_2: 0.9600 - val_recall_2: 0.6985
# Epoch 24/150
# 4/4 [==============================] - 2s 448ms/step - loss: 0.1960 - accuracy: 0.9385 - precision_2: 0.9186 - recall_2: 0.5925 - val_loss: 0.1306 - val_accuracy: 0.9401 - val_precision_2: 0.5565 - val_recall_2: 0.8900
# Epoch 25/150
# 4/4 [==============================] - 2s 447ms/step - loss: 0.1968 - accuracy: 0.9451 - precision_2: 0.8741 - recall_2: 0.6883 - val_loss: 0.0935 - val_accuracy: 0.9785 - val_precision_2: 0.8776 - val_recall_2: 0.8199
# Epoch 26/150
# 4/4 [==============================] - 2s 447ms/step - loss: 0.1896 - accuracy: 0.9453 - precision_2: 0.8729 - recall_2: 0.6912 - val_loss: 0.1259 - val_accuracy: 0.9357 - val_precision_2: 0.5350 - val_recall_2: 0.9167
# Epoch 27/150
# 4/4 [==============================] - 2s 446ms/step - loss: 0.1927 - accuracy: 0.9452 - precision_2: 0.8749 - recall_2: 0.6881 - val_loss: 0.0970 - val_accuracy: 0.9695 - val_precision_2: 0.7456 - val_recall_2: 0.8836
# Epoch 28/150
# 4/4 [==============================] - 2s 446ms/step - loss: 0.1725 - accuracy: 0.9536 - precision_2: 0.8548 - recall_2: 0.7868 - val_loss: 0.1132 - val_accuracy: 0.9440 - val_precision_2: 0.5719 - val_recall_2: 0.9312
# Epoch 29/150
# 4/4 [==============================] - 2s 446ms/step - loss: 0.1663 - accuracy: 0.9543 - precision_2: 0.8704 - recall_2: 0.7731 - val_loss: 0.0981 - val_accuracy: 0.9581 - val_precision_2: 0.6457 - val_recall_2: 0.9469
# Epoch 30/150
# 4/4 [==============================] - 2s 441ms/step - loss: 0.1560 - accuracy: 0.9490 - precision_2: 0.7940 - recall_2: 0.8354 - val_loss: 0.0583 - val_accuracy: 0.9825 - val_precision_2: 0.8754 - val_recall_2: 0.8876
# Epoch 31/150
# 4/4 [==============================] - 2s 445ms/step - loss: 0.1641 - accuracy: 0.9488 - precision_2: 0.8302 - recall_2: 0.7760 - val_loss: 0.0888 - val_accuracy: 0.9583 - val_precision_2: 0.6490 - val_recall_2: 0.9352
# Epoch 32/150
# 4/4 [==============================] - 2s 443ms/step - loss: 0.1458 - accuracy: 0.9555 - precision_2: 0.8929 - recall_2: 0.7576 - val_loss: 0.0859 - val_accuracy: 0.9587 - val_precision_2: 0.6505 - val_recall_2: 0.9395
# Epoch 33/150
# 4/4 [==============================] - 2s 446ms/step - loss: 0.1497 - accuracy: 0.9528 - precision_2: 0.8518 - recall_2: 0.7827 - val_loss: 0.0619 - val_accuracy: 0.9805 - val_precision_2: 0.8424 - val_recall_2: 0.9026
# Epoch 34/150
# 4/4 [==============================] - 2s 450ms/step - loss: 0.1557 - accuracy: 0.9552 - precision_2: 0.8835 - recall_2: 0.7661 - val_loss: 0.1562 - val_accuracy: 0.9192 - val_precision_2: 0.4744 - val_recall_2: 0.9747
# Epoch 35/150
# 4/4 [==============================] - 2s 445ms/step - loss: 0.1723 - accuracy: 0.9435 - precision_2: 0.8459 - recall_2: 0.7062 - val_loss: 0.0880 - val_accuracy: 0.9598 - val_precision_2: 0.6571 - val_recall_2: 0.9421
# Epoch 36/150
# 4/4 [==============================] - 2s 442ms/step - loss: 0.1616 - accuracy: 0.9442 - precision_2: 0.7763 - recall_2: 0.8183 - val_loss: 0.0593 - val_accuracy: 0.9843 - val_precision_2: 0.8834 - val_recall_2: 0.9052
# Epoch 37/150
# 4/4 [==============================] - 2s 453ms/step - loss: 0.1654 - accuracy: 0.9448 - precision_2: 0.9304 - recall_2: 0.6342 - val_loss: 0.0928 - val_accuracy: 0.9580 - val_precision_2: 0.6437 - val_recall_2: 0.9531
# Epoch 38/150
# 4/4 [==============================] - 2s 447ms/step - loss: 0.1577 - accuracy: 0.9535 - precision_2: 0.8092 - recall_2: 0.8530 - val_loss: 0.0556 - val_accuracy: 0.9849 - val_precision_2: 0.9207 - val_recall_2: 0.8680
# Epoch 39/150
# 4/4 [==============================] - 2s 445ms/step - loss: 0.1661 - accuracy: 0.9444 - precision_2: 0.9428 - recall_2: 0.6222 - val_loss: 0.1336 - val_accuracy: 0.9310 - val_precision_2: 0.5154 - val_recall_2: 0.9478
# Epoch 40/150
# 4/4 [==============================] - 2s 453ms/step - loss: 0.1556 - accuracy: 0.9564 - precision_2: 0.8297 - recall_2: 0.8476 - val_loss: 0.0578 - val_accuracy: 0.9811 - val_precision_2: 0.8595 - val_recall_2: 0.8865
# Epoch 41/150
# 4/4 [==============================] - 2s 456ms/step - loss: 0.1660 - accuracy: 0.9490 - precision_2: 0.9219 - recall_2: 0.6758 - val_loss: 0.1873 - val_accuracy: 0.9191 - val_precision_2: 0.4740 - val_recall_2: 0.9746
# Epoch 42/150
# 4/4 [==============================] - 2s 452ms/step - loss: 0.1591 - accuracy: 0.9478 - precision_2: 0.8110 - recall_2: 0.7943 - val_loss: 0.0582 - val_accuracy: 0.9858 - val_precision_2: 0.9147 - val_recall_2: 0.8881
# Epoch 43/150
# 4/4 [==============================] - 2s 446ms/step - loss: 0.1459 - accuracy: 0.9562 - precision_2: 0.9240 - recall_2: 0.7324 - val_loss: 0.0807 - val_accuracy: 0.9722 - val_precision_2: 0.7429 - val_recall_2: 0.9482
# Epoch 44/150
# 4/4 [==============================] - 2s 448ms/step - loss: 0.1362 - accuracy: 0.9604 - precision_2: 0.9041 - recall_2: 0.7874 - val_loss: 0.0715 - val_accuracy: 0.9711 - val_precision_2: 0.7312 - val_recall_2: 0.9558
# Epoch 45/150
# 4/4 [==============================] - 2s 442ms/step - loss: 0.1420 - accuracy: 0.9573 - precision_2: 0.8496 - recall_2: 0.8271 - val_loss: 0.0734 - val_accuracy: 0.9680 - val_precision_2: 0.7080 - val_recall_2: 0.9570
# Epoch 46/150
# 4/4 [==============================] - 2s 453ms/step - loss: 0.1590 - accuracy: 0.9534 - precision_2: 0.9292 - recall_2: 0.7053 - val_loss: 0.1155 - val_accuracy: 0.9402 - val_precision_2: 0.5520 - val_recall_2: 0.9651
# Epoch 47/150
# 4/4 [==============================] - 2s 445ms/step - loss: 0.1448 - accuracy: 0.9598 - precision_2: 0.8463 - recall_2: 0.8547 - val_loss: 0.1015 - val_accuracy: 0.9497 - val_precision_2: 0.5968 - val_recall_2: 0.9592
# Epoch 48/150
# 4/4 [==============================] - 2s 443ms/step - loss: 0.1379 - accuracy: 0.9567 - precision_2: 0.9137 - recall_2: 0.7464 - val_loss: 0.0544 - val_accuracy: 0.9846 - val_precision_2: 0.8642 - val_recall_2: 0.9357
# Epoch 49/150
# 4/4 [==============================] - 2s 452ms/step - loss: 0.1302 - accuracy: 0.9620 - precision_2: 0.8814 - recall_2: 0.8273 - val_loss: 0.1560 - val_accuracy: 0.9276 - val_precision_2: 0.5024 - val_recall_2: 0.9772
# Epoch 50/150
# 4/4 [==============================] - 2s 449ms/step - loss: 0.1380 - accuracy: 0.9591 - precision_2: 0.8777 - recall_2: 0.8064 - val_loss: 0.0576 - val_accuracy: 0.9806 - val_precision_2: 0.8112 - val_recall_2: 0.9566
# Epoch 51/150
# 4/4 [==============================] - 2s 445ms/step - loss: 0.1380 - accuracy: 0.9598 - precision_2: 0.8632 - recall_2: 0.8310 - val_loss: 0.1196 - val_accuracy: 0.9429 - val_precision_2: 0.5633 - val_recall_2: 0.9711
# Epoch 52/150
# 4/4 [==============================] - 2s 447ms/step - loss: 0.1315 - accuracy: 0.9598 - precision_2: 0.9159 - recall_2: 0.7702 - val_loss: 0.0780 - val_accuracy: 0.9671 - val_precision_2: 0.7011 - val_recall_2: 0.9584
# Epoch 53/150
# 4/4 [==============================] - 2s 450ms/step - loss: 0.1366 - accuracy: 0.9533 - precision_2: 0.8247 - recall_2: 0.8261 - val_loss: 0.0451 - val_accuracy: 0.9878 - val_precision_2: 0.9045 - val_recall_2: 0.9307
# Epoch 54/150
# 4/4 [==============================] - 2s 451ms/step - loss: 0.1418 - accuracy: 0.9513 - precision_2: 0.9339 - recall_2: 0.6842 - val_loss: 0.0810 - val_accuracy: 0.9685 - val_precision_2: 0.7102 - val_recall_2: 0.9622
# Epoch 55/150
# 4/4 [==============================] - 2s 447ms/step - loss: 0.1241 - accuracy: 0.9631 - precision_2: 0.8733 - recall_2: 0.8467 - val_loss: 0.1073 - val_accuracy: 0.9470 - val_precision_2: 0.5824 - val_recall_2: 0.9700
# Epoch 56/150
# 4/4 [==============================] - 2s 450ms/step - loss: 0.1389 - accuracy: 0.9637 - precision_2: 0.9002 - recall_2: 0.8191 - val_loss: 0.1346 - val_accuracy: 0.9369 - val_precision_2: 0.5378 - val_recall_2: 0.9775
# Epoch 57/150
# 4/4 [==============================] - 2s 446ms/step - loss: 0.1347 - accuracy: 0.9613 - precision_2: 0.8385 - recall_2: 0.8802 - val_loss: 0.0577 - val_accuracy: 0.9842 - val_precision_2: 0.8489 - val_recall_2: 0.9541
# Epoch 58/150
# 4/4 [==============================] - 2s 443ms/step - loss: 0.1302 - accuracy: 0.9566 - precision_2: 0.9379 - recall_2: 0.7232 - val_loss: 0.0564 - val_accuracy: 0.9862 - val_precision_2: 0.8813 - val_recall_2: 0.9380
# Epoch 59/150
# 4/4 [==============================] - 2s 448ms/step - loss: 0.1208 - accuracy: 0.9622 - precision_2: 0.9041 - recall_2: 0.8023 - val_loss: 0.1425 - val_accuracy: 0.9343 - val_precision_2: 0.5273 - val_recall_2: 0.9717
# Epoch 60/150
# 4/4 [==============================] - 2s 449ms/step - loss: 0.1185 - accuracy: 0.9629 - precision_2: 0.8867 - recall_2: 0.8279 - val_loss: 0.1377 - val_accuracy: 0.9394 - val_precision_2: 0.5483 - val_recall_2: 0.9697
# Epoch 61/150
# 4/4 [==============================] - 2s 450ms/step - loss: 0.1151 - accuracy: 0.9644 - precision_2: 0.8960 - recall_2: 0.8300 - val_loss: 0.1390 - val_accuracy: 0.9348 - val_precision_2: 0.5293 - val_recall_2: 0.9747
# Epoch 62/150
# 4/4 [==============================] - 2s 447ms/step - loss: 0.1145 - accuracy: 0.9627 - precision_2: 0.8768 - recall_2: 0.8387 - val_loss: 0.0654 - val_accuracy: 0.9738 - val_precision_2: 0.7524 - val_recall_2: 0.9568
# Epoch 63/150
# 4/4 [==============================] - 2s 448ms/step - loss: 0.1171 - accuracy: 0.9600 - precision_2: 0.8852 - recall_2: 0.8055 - val_loss: 0.1611 - val_accuracy: 0.9261 - val_precision_2: 0.4973 - val_recall_2: 0.9798
# Epoch 64/150
# 4/4 [==============================] - 2s 446ms/step - loss: 0.1069 - accuracy: 0.9658 - precision_2: 0.8998 - recall_2: 0.8374 - val_loss: 0.0800 - val_accuracy: 0.9642 - val_precision_2: 0.6804 - val_recall_2: 0.9628
# Epoch 65/150
# 4/4 [==============================] - 2s 449ms/step - loss: 0.1180 - accuracy: 0.9601 - precision_2: 0.8677 - recall_2: 0.8281 - val_loss: 0.0756 - val_accuracy: 0.9668 - val_precision_2: 0.6986 - val_recall_2: 0.9596
# Epoch 66/150
# 4/4 [==============================] - 2s 446ms/step - loss: 0.1072 - accuracy: 0.9641 - precision_2: 0.9284 - recall_2: 0.7923 - val_loss: 0.1875 - val_accuracy: 0.9220 - val_precision_2: 0.4835 - val_recall_2: 0.9840
# Epoch 67/150
# 4/4 [==============================] - 2s 441ms/step - loss: 0.1057 - accuracy: 0.9648 - precision_2: 0.8717 - recall_2: 0.8643 - val_loss: 0.0829 - val_accuracy: 0.9614 - val_precision_2: 0.6619 - val_recall_2: 0.9653
# Epoch 68/150
# 4/4 [==============================] - 2s 446ms/step - loss: 0.1066 - accuracy: 0.9636 - precision_2: 0.9117 - recall_2: 0.8059 - val_loss: 0.1672 - val_accuracy: 0.9227 - val_precision_2: 0.4858 - val_recall_2: 0.9806
# Epoch 69/150
# 4/4 [==============================] - 2s 452ms/step - loss: 0.0988 - accuracy: 0.9675 - precision_2: 0.8935 - recall_2: 0.8592 - val_loss: 0.1294 - val_accuracy: 0.9422 - val_precision_2: 0.5605 - val_recall_2: 0.9721
# Epoch 70/150
# 4/4 [==============================] - 2s 445ms/step - loss: 0.0992 - accuracy: 0.9671 - precision_2: 0.9055 - recall_2: 0.8420 - val_loss: 0.1457 - val_accuracy: 0.9328 - val_precision_2: 0.5216 - val_recall_2: 0.9766
# Epoch 71/150
# 4/4 [==============================] - 2s 448ms/step - loss: 0.0970 - accuracy: 0.9676 - precision_2: 0.9010 - recall_2: 0.8513 - val_loss: 0.2050 - val_accuracy: 0.9142 - val_precision_2: 0.4597 - val_recall_2: 0.9886
# Epoch 72/150
# 4/4 [==============================] - 2s 446ms/step - loss: 0.0975 - accuracy: 0.9667 - precision_2: 0.8919 - recall_2: 0.8547 - val_loss: 0.1008 - val_accuracy: 0.9550 - val_precision_2: 0.6235 - val_recall_2: 0.9689
# Epoch 73/150
# 4/4 [==============================] - 2s 444ms/step - loss: 0.0947 - accuracy: 0.9668 - precision_2: 0.9061 - recall_2: 0.8389 - val_loss: 0.1276 - val_accuracy: 0.9386 - val_precision_2: 0.5448 - val_recall_2: 0.9766
# Epoch 74/150
# 4/4 [==============================] - 2s 451ms/step - loss: 0.0900 - accuracy: 0.9683 - precision_2: 0.9109 - recall_2: 0.8452 - val_loss: 0.1864 - val_accuracy: 0.9195 - val_precision_2: 0.4754 - val_recall_2: 0.9837
# Epoch 75/150
# 4/4 [==============================] - 2s 452ms/step - loss: 0.0984 - accuracy: 0.9661 - precision_2: 0.8664 - recall_2: 0.8828 - val_loss: 0.1208 - val_accuracy: 0.9405 - val_precision_2: 0.5530 - val_recall_2: 0.9742
# Epoch 76/150
# 4/4 [==============================] - 2s 449ms/step - loss: 0.0930 - accuracy: 0.9671 - precision_2: 0.9204 - recall_2: 0.8256 - val_loss: 0.1352 - val_accuracy: 0.9385 - val_precision_2: 0.5443 - val_recall_2: 0.9754
# Epoch 77/150
# 4/4 [==============================] - 2s 456ms/step - loss: 0.0837 - accuracy: 0.9690 - precision_2: 0.8950 - recall_2: 0.8701 - val_loss: 0.1996 - val_accuracy: 0.9249 - val_precision_2: 0.4931 - val_recall_2: 0.9809
# Epoch 78/150
# 4/4 [==============================] - 2s 446ms/step - loss: 0.0880 - accuracy: 0.9687 - precision_2: 0.9040 - recall_2: 0.8572 - val_loss: 0.2383 - val_accuracy: 0.9084 - val_precision_2: 0.4434 - val_recall_2: 0.9912
# Epoch 79/150
# 4/4 [==============================] - 2s 449ms/step - loss: 0.0948 - accuracy: 0.9655 - precision_2: 0.8878 - recall_2: 0.8492 - val_loss: 0.1410 - val_accuracy: 0.9345 - val_precision_2: 0.5280 - val_recall_2: 0.9774
# Epoch 80/150
# 4/4 [==============================] - 2s 451ms/step - loss: 0.0844 - accuracy: 0.9684 - precision_2: 0.8748 - recall_2: 0.8913 - val_loss: 0.1237 - val_accuracy: 0.9422 - val_precision_2: 0.5597 - val_recall_2: 0.9795
# Epoch 81/150
# 4/4 [==============================] - 2s 449ms/step - loss: 0.0900 - accuracy: 0.9672 - precision_2: 0.9044 - recall_2: 0.8440 - val_loss: 0.2350 - val_accuracy: 0.9146 - val_precision_2: 0.4606 - val_recall_2: 0.9864
# Epoch 82/150
# 4/4 [==============================] - 2s 445ms/step - loss: 0.0952 - accuracy: 0.9630 - precision_2: 0.8792 - recall_2: 0.8384 - val_loss: 0.0585 - val_accuracy: 0.9714 - val_precision_2: 0.7289 - val_recall_2: 0.9686
# Epoch 83/150
# 4/4 [==============================] - 2s 449ms/step - loss: 0.0913 - accuracy: 0.9618 - precision_2: 0.8616 - recall_2: 0.8510 - val_loss: 0.2188 - val_accuracy: 0.9188 - val_precision_2: 0.4732 - val_recall_2: 0.9854
# Epoch 84/150
# 4/4 [==============================] - 2s 445ms/step - loss: 0.1141 - accuracy: 0.9648 - precision_2: 0.9020 - recall_2: 0.8267 - val_loss: 0.1448 - val_accuracy: 0.9192 - val_precision_2: 0.4744 - val_recall_2: 0.9835
# Epoch 85/150
# 4/4 [==============================] - 2s 444ms/step - loss: 0.1017 - accuracy: 0.9677 - precision_2: 0.8712 - recall_2: 0.8898 - val_loss: 0.1523 - val_accuracy: 0.9371 - val_precision_2: 0.5382 - val_recall_2: 0.9794
# Epoch 86/150
# 4/4 [==============================] - 2s 444ms/step - loss: 0.0874 - accuracy: 0.9679 - precision_2: 0.9169 - recall_2: 0.8355 - val_loss: 0.1909 - val_accuracy: 0.9321 - val_precision_2: 0.5189 - val_recall_2: 0.9816
# Epoch 87/150
# 4/4 [==============================] - 2s 452ms/step - loss: 0.0805 - accuracy: 0.9694 - precision_2: 0.8950 - recall_2: 0.8734 - val_loss: 0.1844 - val_accuracy: 0.9239 - val_precision_2: 0.4897 - val_recall_2: 0.9811
# Epoch 88/150
# 4/4 [==============================] - 2s 445ms/step - loss: 0.0783 - accuracy: 0.9694 - precision_2: 0.9013 - recall_2: 0.8660 - val_loss: 0.1557 - val_accuracy: 0.9293 - val_precision_2: 0.5086 - val_recall_2: 0.9801
# Epoch 89/150
# 4/4 [==============================] - 2s 449ms/step - loss: 0.0742 - accuracy: 0.9702 - precision_2: 0.9043 - recall_2: 0.8687 - val_loss: 0.1789 - val_accuracy: 0.9302 - val_precision_2: 0.5117 - val_recall_2: 0.9840
# Epoch 90/150
# 4/4 [==============================] - 2s 444ms/step - loss: 0.0718 - accuracy: 0.9713 - precision_2: 0.8931 - recall_2: 0.8918 - val_loss: 0.0968 - val_accuracy: 0.9561 - val_precision_2: 0.6274 - val_recall_2: 0.9826
# Epoch 91/150
# 4/4 [==============================] - 2s 446ms/step - loss: 0.0725 - accuracy: 0.9725 - precision_2: 0.8972 - recall_2: 0.8967 - val_loss: 0.1619 - val_accuracy: 0.9289 - val_precision_2: 0.5071 - val_recall_2: 0.9830
# Epoch 92/150
# 4/4 [==============================] - 2s 450ms/step - loss: 0.0660 - accuracy: 0.9746 - precision_2: 0.8976 - recall_2: 0.9144 - val_loss: 0.1393 - val_accuracy: 0.9328 - val_precision_2: 0.5213 - val_recall_2: 0.9831
# Epoch 93/150
# 4/4 [==============================] - 2s 451ms/step - loss: 0.0618 - accuracy: 0.9767 - precision_2: 0.9011 - recall_2: 0.9275 - val_loss: 0.1296 - val_accuracy: 0.9430 - val_precision_2: 0.5635 - val_recall_2: 0.9771
# Epoch 94/150
# 4/4 [==============================] - 2s 452ms/step - loss: 0.0606 - accuracy: 0.9761 - precision_2: 0.9113 - recall_2: 0.9096 - val_loss: 0.1971 - val_accuracy: 0.9235 - val_precision_2: 0.4884 - val_recall_2: 0.9867
# Epoch 95/150
# 4/4 [==============================] - 2s 445ms/step - loss: 0.0602 - accuracy: 0.9760 - precision_2: 0.8987 - recall_2: 0.9249 - val_loss: 0.0935 - val_accuracy: 0.9566 - val_precision_2: 0.6317 - val_recall_2: 0.9742
# Epoch 96/150
# 4/4 [==============================] - 2s 451ms/step - loss: 0.0568 - accuracy: 0.9782 - precision_2: 0.9165 - recall_2: 0.9206 - val_loss: 0.2252 - val_accuracy: 0.9183 - val_precision_2: 0.4720 - val_recall_2: 0.9886
# Epoch 97/150
# 4/4 [==============================] - 2s 448ms/step - loss: 0.0564 - accuracy: 0.9777 - precision_2: 0.9086 - recall_2: 0.9266 - val_loss: 0.0949 - val_accuracy: 0.9589 - val_precision_2: 0.6437 - val_recall_2: 0.9801
# Epoch 98/150
# 4/4 [==============================] - 2s 444ms/step - loss: 0.0531 - accuracy: 0.9799 - precision_2: 0.9125 - recall_2: 0.9401 - val_loss: 0.1736 - val_accuracy: 0.9349 - val_precision_2: 0.5294 - val_recall_2: 0.9841
# Epoch 99/150
# 4/4 [==============================] - 2s 443ms/step - loss: 0.0545 - accuracy: 0.9789 - precision_2: 0.9220 - recall_2: 0.9197 - val_loss: 0.1928 - val_accuracy: 0.9252 - val_precision_2: 0.4943 - val_recall_2: 0.9861
# Epoch 100/150
# 4/4 [==============================] - 2s 450ms/step - loss: 0.0528 - accuracy: 0.9794 - precision_2: 0.9102 - recall_2: 0.9385 - val_loss: 0.1193 - val_accuracy: 0.9507 - val_precision_2: 0.5996 - val_recall_2: 0.9792
# Epoch 101/150
# 4/4 [==============================] - 2s 447ms/step - loss: 0.0529 - accuracy: 0.9794 - precision_2: 0.9181 - recall_2: 0.9288 - val_loss: 0.1618 - val_accuracy: 0.9386 - val_precision_2: 0.5440 - val_recall_2: 0.9868
# Epoch 102/150
# 4/4 [==============================] - 2s 448ms/step - loss: 0.0570 - accuracy: 0.9784 - precision_2: 0.9206 - recall_2: 0.9172 - val_loss: 0.2250 - val_accuracy: 0.9243 - val_precision_2: 0.4911 - val_recall_2: 0.9843
# Epoch 103/150
# 4/4 [==============================] - 2s 449ms/step - loss: 0.0558 - accuracy: 0.9782 - precision_2: 0.9129 - recall_2: 0.9253 - val_loss: 0.1305 - val_accuracy: 0.9454 - val_precision_2: 0.5739 - val_recall_2: 0.9830
# Epoch 104/150
# 4/4 [==============================] - 2s 443ms/step - loss: 0.0616 - accuracy: 0.9788 - precision_2: 0.9242 - recall_2: 0.9169 - val_loss: 0.0942 - val_accuracy: 0.9575 - val_precision_2: 0.6361 - val_recall_2: 0.9793
# Epoch 105/150
# 4/4 [==============================] - 2s 447ms/step - loss: 0.0526 - accuracy: 0.9796 - precision_2: 0.9183 - recall_2: 0.9304 - val_loss: 0.1068 - val_accuracy: 0.9557 - val_precision_2: 0.6256 - val_recall_2: 0.9798
# Epoch 106/150
# 4/4 [==============================] - 2s 451ms/step - loss: 0.0551 - accuracy: 0.9787 - precision_2: 0.9210 - recall_2: 0.9194 - val_loss: 0.2127 - val_accuracy: 0.9305 - val_precision_2: 0.5130 - val_recall_2: 0.9802
# Epoch 107/150
# 4/4 [==============================] - 2s 445ms/step - loss: 0.0467 - accuracy: 0.9816 - precision_2: 0.9290 - recall_2: 0.9337 - val_loss: 0.0929 - val_accuracy: 0.9639 - val_precision_2: 0.6752 - val_recall_2: 0.9750
# Epoch 108/150
# 4/4 [==============================] - 2s 445ms/step - loss: 0.0429 - accuracy: 0.9835 - precision_2: 0.9329 - recall_2: 0.9445 - val_loss: 0.1161 - val_accuracy: 0.9547 - val_precision_2: 0.6211 - val_recall_2: 0.9750
# Epoch 109/150
# 4/4 [==============================] - 2s 448ms/step - loss: 0.0420 - accuracy: 0.9837 - precision_2: 0.9329 - recall_2: 0.9462 - val_loss: 0.1030 - val_accuracy: 0.9606 - val_precision_2: 0.6528 - val_recall_2: 0.9838
# Epoch 110/150
# 4/4 [==============================] - 2s 450ms/step - loss: 0.0405 - accuracy: 0.9841 - precision_2: 0.9357 - recall_2: 0.9463 - val_loss: 0.1835 - val_accuracy: 0.9388 - val_precision_2: 0.5452 - val_recall_2: 0.9793
# Epoch 111/150
# 4/4 [==============================] - 2s 447ms/step - loss: 0.0392 - accuracy: 0.9849 - precision_2: 0.9443 - recall_2: 0.9425 - val_loss: 0.0870 - val_accuracy: 0.9685 - val_precision_2: 0.7047 - val_recall_2: 0.9790
# Epoch 112/150
# 4/4 [==============================] - 2s 453ms/step - loss: 0.0456 - accuracy: 0.9825 - precision_2: 0.9126 - recall_2: 0.9612 - val_loss: 0.0331 - val_accuracy: 0.9873 - val_precision_2: 0.8790 - val_recall_2: 0.9581
# Epoch 113/150
# 4/4 [==============================] - 2s 450ms/step - loss: 0.0534 - accuracy: 0.9795 - precision_2: 0.9508 - recall_2: 0.8927 - val_loss: 0.2683 - val_accuracy: 0.9080 - val_precision_2: 0.4421 - val_recall_2: 0.9873
# Epoch 114/150
# 4/4 [==============================] - 2s 443ms/step - loss: 0.0953 - accuracy: 0.9661 - precision_2: 0.8754 - recall_2: 0.8701 - val_loss: 0.3179 - val_accuracy: 0.9119 - val_precision_2: 0.4528 - val_recall_2: 0.9847
# Epoch 115/150
# 4/4 [==============================] - 2s 448ms/step - loss: 0.0994 - accuracy: 0.9596 - precision_2: 0.8493 - recall_2: 0.8484 - val_loss: 0.0521 - val_accuracy: 0.9806 - val_precision_2: 0.8774 - val_recall_2: 0.8535
# Epoch 116/150
# 4/4 [==============================] - 2s 445ms/step - loss: 0.1040 - accuracy: 0.9614 - precision_2: 0.8701 - recall_2: 0.8365 - val_loss: 0.0958 - val_accuracy: 0.9488 - val_precision_2: 0.5929 - val_recall_2: 0.9539
# Epoch 117/150
# 4/4 [==============================] - 2s 452ms/step - loss: 0.0937 - accuracy: 0.9693 - precision_2: 0.9253 - recall_2: 0.8376 - val_loss: 0.1982 - val_accuracy: 0.9173 - val_precision_2: 0.4688 - val_recall_2: 0.9842
# Epoch 118/150
# 4/4 [==============================] - 2s 449ms/step - loss: 0.0848 - accuracy: 0.9684 - precision_2: 0.8885 - recall_2: 0.8729 - val_loss: 0.0573 - val_accuracy: 0.9753 - val_precision_2: 0.7642 - val_recall_2: 0.9575
# Epoch 119/150
# 4/4 [==============================] - 2s 443ms/step - loss: 0.0667 - accuracy: 0.9738 - precision_2: 0.9307 - recall_2: 0.8684 - val_loss: 0.0915 - val_accuracy: 0.9593 - val_precision_2: 0.6461 - val_recall_2: 0.9804
# Epoch 120/150
# 4/4 [==============================] - 2s 450ms/step - loss: 0.0625 - accuracy: 0.9755 - precision_2: 0.9060 - recall_2: 0.9113 - val_loss: 0.0579 - val_accuracy: 0.9760 - val_precision_2: 0.7629 - val_recall_2: 0.9743
# Epoch 121/150
# 4/4 [==============================] - 2s 447ms/step - loss: 0.0524 - accuracy: 0.9794 - precision_2: 0.9306 - recall_2: 0.9141 - val_loss: 0.0583 - val_accuracy: 0.9753 - val_precision_2: 0.7580 - val_recall_2: 0.9719
# Epoch 122/150
# 4/4 [==============================] - 2s 444ms/step - loss: 0.0471 - accuracy: 0.9819 - precision_2: 0.9172 - recall_2: 0.9503 - val_loss: 0.0753 - val_accuracy: 0.9657 - val_precision_2: 0.6869 - val_recall_2: 0.9757
# Epoch 123/150
# 4/4 [==============================] - 2s 443ms/step - loss: 0.0432 - accuracy: 0.9835 - precision_2: 0.9284 - recall_2: 0.9501 - val_loss: 0.0559 - val_accuracy: 0.9772 - val_precision_2: 0.7729 - val_recall_2: 0.9750
# Epoch 124/150
# 4/4 [==============================] - 2s 444ms/step - loss: 0.0396 - accuracy: 0.9849 - precision_2: 0.9397 - recall_2: 0.9482 - val_loss: 0.0617 - val_accuracy: 0.9754 - val_precision_2: 0.7558 - val_recall_2: 0.9795
# Epoch 125/150
# 4/4 [==============================] - 2s 451ms/step - loss: 0.0383 - accuracy: 0.9852 - precision_2: 0.9406 - recall_2: 0.9490 - val_loss: 0.0637 - val_accuracy: 0.9760 - val_precision_2: 0.7620 - val_recall_2: 0.9774
# Epoch 126/150
# 4/4 [==============================] - 2s 452ms/step - loss: 0.0353 - accuracy: 0.9863 - precision_2: 0.9473 - recall_2: 0.9501 - val_loss: 0.0700 - val_accuracy: 0.9735 - val_precision_2: 0.7400 - val_recall_2: 0.9821
# Epoch 127/150
# 4/4 [==============================] - 2s 441ms/step - loss: 0.0336 - accuracy: 0.9868 - precision_2: 0.9474 - recall_2: 0.9545 - val_loss: 0.0433 - val_accuracy: 0.9854 - val_precision_2: 0.8489 - val_recall_2: 0.9740
# Epoch 128/150
# 4/4 [==============================] - 2s 453ms/step - loss: 0.0317 - accuracy: 0.9876 - precision_2: 0.9542 - recall_2: 0.9533 - val_loss: 0.0876 - val_accuracy: 0.9671 - val_precision_2: 0.6950 - val_recall_2: 0.9808
# Epoch 129/150
# 4/4 [==============================] - 2s 442ms/step - loss: 0.0314 - accuracy: 0.9878 - precision_2: 0.9485 - recall_2: 0.9607 - val_loss: 0.0426 - val_accuracy: 0.9859 - val_precision_2: 0.8589 - val_recall_2: 0.9655
# Epoch 130/150
# 4/4 [==============================] - 2s 448ms/step - loss: 0.0303 - accuracy: 0.9881 - precision_2: 0.9594 - recall_2: 0.9516 - val_loss: 0.0774 - val_accuracy: 0.9714 - val_precision_2: 0.7241 - val_recall_2: 0.9828
# Epoch 131/150
# 4/4 [==============================] - 2s 443ms/step - loss: 0.0301 - accuracy: 0.9883 - precision_2: 0.9538 - recall_2: 0.9589 - val_loss: 0.0420 - val_accuracy: 0.9863 - val_precision_2: 0.8604 - val_recall_2: 0.9705
# Epoch 132/150
# 4/4 [==============================] - 2s 445ms/step - loss: 0.0283 - accuracy: 0.9891 - precision_2: 0.9569 - recall_2: 0.9616 - val_loss: 0.0962 - val_accuracy: 0.9677 - val_precision_2: 0.6987 - val_recall_2: 0.9817
# Epoch 133/150
# 4/4 [==============================] - 2s 443ms/step - loss: 0.0282 - accuracy: 0.9889 - precision_2: 0.9628 - recall_2: 0.9542 - val_loss: 0.0437 - val_accuracy: 0.9856 - val_precision_2: 0.8531 - val_recall_2: 0.9704
# Epoch 134/150
# 4/4 [==============================] - 2s 445ms/step - loss: 0.0268 - accuracy: 0.9895 - precision_2: 0.9560 - recall_2: 0.9661 - val_loss: 0.0564 - val_accuracy: 0.9808 - val_precision_2: 0.8023 - val_recall_2: 0.9784
# Epoch 135/150
# 4/4 [==============================] - 2s 445ms/step - loss: 0.0256 - accuracy: 0.9899 - precision_2: 0.9619 - recall_2: 0.9627 - val_loss: 0.0467 - val_accuracy: 0.9849 - val_precision_2: 0.8419 - val_recall_2: 0.9769
# Epoch 136/150
# 4/4 [==============================] - 2s 450ms/step - loss: 0.0253 - accuracy: 0.9900 - precision_2: 0.9585 - recall_2: 0.9671 - val_loss: 0.0697 - val_accuracy: 0.9776 - val_precision_2: 0.7808 - val_recall_2: 0.9650
# Epoch 137/150
# 4/4 [==============================] - 2s 449ms/step - loss: 0.0245 - accuracy: 0.9902 - precision_2: 0.9686 - recall_2: 0.9578 - val_loss: 0.0510 - val_accuracy: 0.9844 - val_precision_2: 0.8368 - val_recall_2: 0.9772
# Epoch 138/150
# 4/4 [==============================] - 2s 450ms/step - loss: 0.0263 - accuracy: 0.9897 - precision_2: 0.9591 - recall_2: 0.9643 - val_loss: 0.0616 - val_accuracy: 0.9807 - val_precision_2: 0.8016 - val_recall_2: 0.9773
# Epoch 139/150
# 4/4 [==============================] - 2s 446ms/step - loss: 0.0240 - accuracy: 0.9904 - precision_2: 0.9652 - recall_2: 0.9631 - val_loss: 0.0607 - val_accuracy: 0.9800 - val_precision_2: 0.7979 - val_recall_2: 0.9732
# Epoch 140/150
# 4/4 [==============================] - 2s 444ms/step - loss: 0.0235 - accuracy: 0.9908 - precision_2: 0.9610 - recall_2: 0.9706 - val_loss: 0.0419 - val_accuracy: 0.9869 - val_precision_2: 0.8691 - val_recall_2: 0.9670
# Epoch 141/150
# 4/4 [==============================] - 2s 437ms/step - loss: 0.0227 - accuracy: 0.9912 - precision_2: 0.9719 - recall_2: 0.9616 - val_loss: 0.0567 - val_accuracy: 0.9828 - val_precision_2: 0.8220 - val_recall_2: 0.9760
# Epoch 142/150
# 4/4 [==============================] - 2s 442ms/step - loss: 0.0243 - accuracy: 0.9907 - precision_2: 0.9595 - recall_2: 0.9713 - val_loss: 0.0675 - val_accuracy: 0.9787 - val_precision_2: 0.7929 - val_recall_2: 0.9594
# Epoch 143/150
# 4/4 [==============================] - 2s 442ms/step - loss: 0.0241 - accuracy: 0.9905 - precision_2: 0.9742 - recall_2: 0.9541 - val_loss: 0.0819 - val_accuracy: 0.9752 - val_precision_2: 0.7529 - val_recall_2: 0.9831
# Epoch 144/150
# 4/4 [==============================] - 2s 453ms/step - loss: 0.0268 - accuracy: 0.9893 - precision_2: 0.9443 - recall_2: 0.9780 - val_loss: 0.0447 - val_accuracy: 0.9870 - val_precision_2: 0.8710 - val_recall_2: 0.9659
# Epoch 145/150
# 4/4 [==============================] - 2s 441ms/step - loss: 0.0244 - accuracy: 0.9904 - precision_2: 0.9774 - recall_2: 0.9501 - val_loss: 0.1310 - val_accuracy: 0.9583 - val_precision_2: 0.6404 - val_recall_2: 0.9786
# Epoch 146/150
# 4/4 [==============================] - 2s 448ms/step - loss: 0.0242 - accuracy: 0.9906 - precision_2: 0.9587 - recall_2: 0.9716 - val_loss: 0.0490 - val_accuracy: 0.9841 - val_precision_2: 0.8432 - val_recall_2: 0.9617
# Epoch 147/150
# 4/4 [==============================] - 2s 443ms/step - loss: 0.0220 - accuracy: 0.9915 - precision_2: 0.9733 - recall_2: 0.9626 - val_loss: 0.0850 - val_accuracy: 0.9742 - val_precision_2: 0.7464 - val_recall_2: 0.9810
# Epoch 148/150
# 4/4 [==============================] - 2s 451ms/step - loss: 0.0218 - accuracy: 0.9913 - precision_2: 0.9631 - recall_2: 0.9721 - val_loss: 0.0581 - val_accuracy: 0.9824 - val_precision_2: 0.8227 - val_recall_2: 0.9670
# Epoch 149/150
# 4/4 [==============================] - 2s 445ms/step - loss: 0.0209 - accuracy: 0.9917 - precision_2: 0.9729 - recall_2: 0.9651 - val_loss: 0.1351 - val_accuracy: 0.9621 - val_precision_2: 0.6641 - val_recall_2: 0.9749
# Epoch 150/150
# 4/4 [==============================] - 2s 446ms/step - loss: 0.0202 - accuracy: 0.9921 - precision_2: 0.9670 - recall_2: 0.9744 - val_loss: 0.0463 - val_accuracy: 0.9859 - val_precision_2: 0.8604 - val_recall_2: 0.9626

# %%
model.evaluate(X_train,Y_train)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.0791 - accuracy: 0.9754 - precision_2: 0.8463 - recall_2: 0.9743
# [0.07910944521427155,
#  0.9753576517105103,
#  0.8462722897529602,
#  0.9742631316184998]

# %%
print(history.history.keys())
plt.figure(figsize=(10,10))
plt.subplot(221)
plt.plot(history.history['precision_2'])
plt.plot(history.history['val_precision_2'])
plt.title('model precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')

plt.subplot(222)
plt.plot(history.history['recall_2'])
plt.plot(history.history['val_recall_2'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
# Out:
# dict_keys(['loss', 'accuracy', 'precision_2', 'recall_2', 'val_loss', 'val_accuracy', 'val_precision_2', 'val_recall_2'])

# %%
n = np.random.randint(0,15)
X_test = X_train[n]
Y_test = Y_train[n] 

plt.figure(figsize=(15,15))
plt.subplot(441)
plt.imshow(X_test)
plt.title('Testing RGB')

plt.subplot(442)
plt.imshow(Y_test)
plt.title('Testing Mask')
print(X_test.shape)
print(Y_test.shape)


testing = np.expand_dims(X_test,axis=0)
pred = model.predict(testing,verbose=1)
preds = np.argmax(pred,axis=-1)

plt.figure(figsize=(15,15))
plt.subplot(444)
plt.imshow(np.squeeze(pred>=0.95))
plt.title('Predictions')
plt.subplot(443)
plt.imshow(X_test)
plt.title('Testing RGB')
# Out:
# (512, 512, 3)
# (512, 512)
# 1/1 [==============================] - 0s 20ms/step
# Text(0.5, 1.0, 'Testing RGB')

# %%
model.save('/content/Toby_unet_building_detection_epoch150.h5')
