# %% [markdown]
# <a href="https://colab.research.google.com/github/Aye-Nyein-Thaw/Building-Footprint-Extraction-Practical-Project/blob/toby/Toby's_Unet_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import os
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

# %%
os.chdir('/content/drive/MyDrive/Unet_test/2.Image part')

# %%
ls
# Out:
# 'Binary Mask'/  'Processed Image'/

# %%
train_path = 'Processed Image/'
test_path = 'Binary Mask/'

img_height =512 
img_width = 512
img_channels = 3

train_ids = sorted(next(os.walk(train_path)) [2])
print(train_ids[0])
test_ids = sorted(next(os.walk(test_path)) [2])
print(test_ids[0])
# Out:
# processed_image+final_00001_a0.png
# mask_00001_a0.png

# %%
sorted(test_ids)
# Out:
# ['mask_00001_a0.png',
#  'mask_00002_a0.png',
#  'mask_00003_a0.png',
#  'mask_00004_a0.png',
#  'mask_00005_a0.png',
#  'mask_00006_a0.png',
#  'mask_00007_a0.png',
#  'mask_00008_a0.png',
#  'mask_00009_a0.png',
#  'mask_00010_a0.png',
#  'mask_00011_a0.png',
#  'mask_00012_a0.png',
#  'mask_00013_a0.png',
#  'mask_00014_a0.png',
#  'mask_00015_a0.png',
#  'mask_00016_a0.png',
#  'mask_00017_a0.png',
#  'mask_00018_a0.png',
#  'mask_00019_a0.png',
#  'mask_00020_a0.png']

# %%
train_ids
# Out:
# ['processed_image+final_00001_a0.png',
#  'processed_image+final_00002_a0.png',
#  'processed_image+final_00003_a0.png',
#  'processed_image+final_00004_a0.png',
#  'processed_image+final_00005_a0.png',
#  'processed_image+final_00006_a0.png',
#  'processed_image+final_00007_a0.png',
#  'processed_image+final_00008_a0.png',
#  'processed_image+final_00009_a0.png',
#  'processed_image+final_00010_a0.png',
#  'processed_image+final_00011_a0.png',
#  'processed_image+final_00012_a0.png',
#  'processed_image+final_00013_a0.png',
#  'processed_image+final_00014_a0.png',
#  'processed_image+final_00015_a0.png',
#  'processed_image+final_00016_a0.png',
#  'processed_image+final_00017_a0.png',
#  'processed_image+final_00018_a0.png',
#  'processed_image+final_00019_a0.png',
#  'processed_image+final_00020_a0.png']

# %%
print(len(train_ids))
print(len(test_ids))
# Out:
# 20
# 20

# %%
X_train = np.zeros((len(train_ids),img_height, img_width, img_channels ), dtype=np.uint8)
Y_train = np.zeros((len(test_ids),img_height,img_width),dtype=np.bool)

# %%
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = train_path + id_
    print(path)
    img = Image.open(path)
    X_train[n]=img
# Out:
#  40%|████      | 8/20 [00:00<00:00, 72.86it/s]
# Processed Image/processed_image+final_00001_a0.png
# Processed Image/processed_image+final_00002_a0.png
# Processed Image/processed_image+final_00003_a0.png
# Processed Image/processed_image+final_00004_a0.png
# Processed Image/processed_image+final_00005_a0.png
# Processed Image/processed_image+final_00006_a0.png
# Processed Image/processed_image+final_00007_a0.png
# Processed Image/processed_image+final_00008_a0.png
# Processed Image/processed_image+final_00009_a0.png
# Processed Image/processed_image+final_00010_a0.png
# Processed Image/processed_image+final_00011_a0.png
# Processed Image/processed_image+final_00012_a0.png
# Processed Image/processed_image+final_00013_a0.png
# Processed Image/processed_image+final_00014_a0.png
# 100%|██████████| 20/20 [00:00<00:00, 74.04it/s]
# Processed Image/processed_image+final_00015_a0.png
# Processed Image/processed_image+final_00016_a0.png
# Processed Image/processed_image+final_00017_a0.png
# Processed Image/processed_image+final_00018_a0.png
# Processed Image/processed_image+final_00019_a0.png
# Processed Image/processed_image+final_00020_a0.png

# %%
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path_test = test_path + id_
    print(path_test)
    mask = Image.open(path_test)
    Y_train[n]=mask
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 483.83it/s]
# Binary Mask/mask_00001_a0.png
# Binary Mask/mask_00002_a0.png
# Binary Mask/mask_00003_a0.png
# Binary Mask/mask_00004_a0.png
# Binary Mask/mask_00005_a0.png
# Binary Mask/mask_00006_a0.png
# Binary Mask/mask_00007_a0.png
# Binary Mask/mask_00008_a0.png
# Binary Mask/mask_00009_a0.png
# Binary Mask/mask_00010_a0.png
# Binary Mask/mask_00011_a0.png
# Binary Mask/mask_00012_a0.png
# Binary Mask/mask_00013_a0.png
# Binary Mask/mask_00014_a0.png
# Binary Mask/mask_00015_a0.png
# Binary Mask/mask_00016_a0.png
# Binary Mask/mask_00017_a0.png
# Binary Mask/mask_00018_a0.png
# Binary Mask/mask_00019_a0.png
# Binary Mask/mask_00020_a0.png

# %%
def plotting (x ,y):
  n = np.random.randint(0,20)
  plt.subplot(121)
  plt.imshow(x[n])
  plt.subplot(122)
  plt.imshow(y[n])

plotting(X_train,Y_train)

# %%
#X_train_new = X_train/255
#Y_train_new = Y_train/255
#plotting(X_train_new,Y_t  rain_new)

#img_size = 512
#num_classes =2 

plotting(X_train,Y_train)

print(X_train[n].shape)
print(Y_train[n].shape)
# Out:
# (512, 512, 3)
# (512, 512)

# %%
#Build the model
IMG_HEIGHT = 512
IMG_WIDTH = 512
IMG_CHANNELS = 3
inputs = tf.keras.layers.Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = tf.keras.layers.Lambda(lambda x: x / 255)(inputs)

#Contraction path
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)
 
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
c3 = tf.keras.layers.Dropout(0.2)(c3)
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)
 
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
c4 = tf.keras.layers.Dropout(0.2)(c4)
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c4)
 
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
c5 = tf.keras.layers.Dropout(0.3)(c5)
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

#Expansive path 
u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = tf.keras.layers.concatenate([u6, c4])
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
c6 = tf.keras.layers.Dropout(0.2)(c6)
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
 
u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
u7 = tf.keras.layers.concatenate([u7, c3])
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
c7 = tf.keras.layers.Dropout(0.2)(c7)
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)
 
u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
u8 = tf.keras.layers.concatenate([u8, c2])
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
c8 = tf.keras.layers.Dropout(0.1)(c8)
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
 
u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
c9 = tf.keras.layers.Dropout(0.1)(c9)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
 
outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)
 
model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#model.summary()

# %%
#Build the model
IMG_HEIGHT = 512
IMG_WIDTH = 512
IMG_CHANNELS = 3
inputs = tf.keras.layers.Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = tf.keras.layers.Lambda(lambda x: x / 255)(inputs)

#Contraction path
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)
 
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
c3 = tf.keras.layers.Dropout(0.2)(c3)
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)
 
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
c4 = tf.keras.layers.Dropout(0.2)(c4)
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c4)
 
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
c5 = tf.keras.layers.Dropout(0.3)(c5)
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

#Expansive path 
u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = tf.keras.layers.concatenate([u6, c4])
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(u6)
c6 = tf.keras.layers.Dropout(0.2)(c6)
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c6)
 
u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
u7 = tf.keras.layers.concatenate([u7, c3])
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(u7)
c7 = tf.keras.layers.Dropout(0.2)(c7)
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c7)
 
u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
u8 = tf.keras.layers.concatenate([u8, c2])
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(u8)
c8 = tf.keras.layers.Dropout(0.1)(c8)
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(c8)
 
u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(u9)
c9 = tf.keras.layers.Dropout(0.1)(c9)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(c9)
 
outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)
 
model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#model.summary()

# %%
history = model.fit(X_train,Y_train,epochs=100,verbose = 1, batch_size=4,validation_split=0.2)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 2s 242ms/step - loss: 0.5757 - accuracy: 0.7851 - val_loss: 0.6092 - val_accuracy: 0.9269
# Epoch 2/100
# 4/4 [==============================] - 1s 156ms/step - loss: 0.4839 - accuracy: 0.8663 - val_loss: 0.5370 - val_accuracy: 0.9269
# Epoch 3/100
# 4/4 [==============================] - 1s 159ms/step - loss: 0.4743 - accuracy: 0.8663 - val_loss: 0.5096 - val_accuracy: 0.9269
# Epoch 4/100
# 4/4 [==============================] - 1s 158ms/step - loss: 0.4300 - accuracy: 0.8663 - val_loss: 0.5209 - val_accuracy: 0.9269
# Epoch 5/100
# 4/4 [==============================] - 1s 158ms/step - loss: 0.4260 - accuracy: 0.8663 - val_loss: 0.4922 - val_accuracy: 0.9269
# Epoch 6/100
# 4/4 [==============================] - 1s 160ms/step - loss: 0.3991 - accuracy: 0.8663 - val_loss: 0.4400 - val_accuracy: 0.9269
# Epoch 7/100
# 4/4 [==============================] - 1s 158ms/step - loss: 0.3610 - accuracy: 0.8663 - val_loss: 0.4147 - val_accuracy: 0.9269
# Epoch 8/100
# 4/4 [==============================] - 1s 159ms/step - loss: 0.3396 - accuracy: 0.8664 - val_loss: 0.3620 - val_accuracy: 0.9269
# Epoch 9/100
# 4/4 [==============================] - 1s 159ms/step - loss: 0.2899 - accuracy: 0.8668 - val_loss: 0.2643 - val_accuracy: 0.9530
# Epoch 10/100
# 4/4 [==============================] - 1s 158ms/step - loss: 0.2499 - accuracy: 0.8947 - val_loss: 0.2721 - val_accuracy: 0.9728
# Epoch 11/100
# 4/4 [==============================] - 1s 157ms/step - loss: 0.2345 - accuracy: 0.9260 - val_loss: 0.1782 - val_accuracy: 0.9662
# Epoch 12/100
# 4/4 [==============================] - 1s 159ms/step - loss: 0.2105 - accuracy: 0.9453 - val_loss: 0.1941 - val_accuracy: 0.9172
# Epoch 13/100
# 4/4 [==============================] - 1s 158ms/step - loss: 0.2222 - accuracy: 0.9469 - val_loss: 0.1916 - val_accuracy: 0.9110
# Epoch 14/100
# 4/4 [==============================] - 1s 159ms/step - loss: 0.2190 - accuracy: 0.9341 - val_loss: 0.1265 - val_accuracy: 0.9674
# Epoch 15/100
# 4/4 [==============================] - 1s 158ms/step - loss: 0.2170 - accuracy: 0.9420 - val_loss: 0.1758 - val_accuracy: 0.9266
# Epoch 16/100
# 4/4 [==============================] - 1s 159ms/step - loss: 0.2102 - accuracy: 0.9468 - val_loss: 0.1387 - val_accuracy: 0.9578
# Epoch 17/100
# 4/4 [==============================] - 1s 159ms/step - loss: 0.2055 - accuracy: 0.9423 - val_loss: 0.0944 - val_accuracy: 0.9752
# Epoch 18/100
# 4/4 [==============================] - 1s 161ms/step - loss: 0.2078 - accuracy: 0.9446 - val_loss: 0.2050 - val_accuracy: 0.9087
# Epoch 19/100
# 4/4 [==============================] - 1s 170ms/step - loss: 0.1846 - accuracy: 0.9461 - val_loss: 0.0801 - val_accuracy: 0.9759
# Epoch 20/100
# 4/4 [==============================] - 1s 160ms/step - loss: 0.1763 - accuracy: 0.9510 - val_loss: 0.1335 - val_accuracy: 0.9375
# Epoch 21/100
# 4/4 [==============================] - 1s 160ms/step - loss: 0.1675 - accuracy: 0.9519 - val_loss: 0.0959 - val_accuracy: 0.9689
# Epoch 22/100
# 4/4 [==============================] - 1s 160ms/step - loss: 0.1650 - accuracy: 0.9525 - val_loss: 0.1345 - val_accuracy: 0.9330
# Epoch 23/100
# 4/4 [==============================] - 1s 160ms/step - loss: 0.1636 - accuracy: 0.9522 - val_loss: 0.1249 - val_accuracy: 0.9374
# Epoch 24/100
# 4/4 [==============================] - 1s 158ms/step - loss: 0.1574 - accuracy: 0.9536 - val_loss: 0.1143 - val_accuracy: 0.9439
# Epoch 25/100
# 4/4 [==============================] - 1s 159ms/step - loss: 0.1576 - accuracy: 0.9541 - val_loss: 0.1687 - val_accuracy: 0.9193
# Epoch 26/100
# 4/4 [==============================] - 1s 159ms/step - loss: 0.1518 - accuracy: 0.9550 - val_loss: 0.2005 - val_accuracy: 0.9082
# Epoch 27/100
# 4/4 [==============================] - 1s 160ms/step - loss: 0.1571 - accuracy: 0.9521 - val_loss: 0.2029 - val_accuracy: 0.9052
# Epoch 28/100
# 4/4 [==============================] - 1s 161ms/step - loss: 0.1596 - accuracy: 0.9524 - val_loss: 0.1357 - val_accuracy: 0.9301
# Epoch 29/100
# 4/4 [==============================] - 1s 159ms/step - loss: 0.1508 - accuracy: 0.9563 - val_loss: 0.1736 - val_accuracy: 0.9130
# Epoch 30/100
# 4/4 [==============================] - 1s 160ms/step - loss: 0.1470 - accuracy: 0.9572 - val_loss: 0.1519 - val_accuracy: 0.9220
# Epoch 31/100
# 4/4 [==============================] - 1s 160ms/step - loss: 0.1437 - accuracy: 0.9575 - val_loss: 0.1765 - val_accuracy: 0.9121
# Epoch 32/100
# 4/4 [==============================] - 1s 161ms/step - loss: 0.1436 - accuracy: 0.9583 - val_loss: 0.1736 - val_accuracy: 0.9125
# Epoch 33/100
# 4/4 [==============================] - 1s 161ms/step - loss: 0.1393 - accuracy: 0.9580 - val_loss: 0.1537 - val_accuracy: 0.9196
# Epoch 34/100
# 4/4 [==============================] - 1s 160ms/step - loss: 0.1415 - accuracy: 0.9576 - val_loss: 0.1862 - val_accuracy: 0.9067
# Epoch 35/100
# 4/4 [==============================] - 1s 161ms/step - loss: 0.1370 - accuracy: 0.9585 - val_loss: 0.1422 - val_accuracy: 0.9245
# Epoch 36/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1568 - accuracy: 0.9464 - val_loss: 0.1354 - val_accuracy: 0.9273
# Epoch 37/100
# 4/4 [==============================] - 1s 161ms/step - loss: 0.1525 - accuracy: 0.9520 - val_loss: 0.1605 - val_accuracy: 0.9179
# Epoch 38/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1428 - accuracy: 0.9579 - val_loss: 0.1207 - val_accuracy: 0.9359
# Epoch 39/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1422 - accuracy: 0.9581 - val_loss: 0.1645 - val_accuracy: 0.9171
# Epoch 40/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1349 - accuracy: 0.9585 - val_loss: 0.1573 - val_accuracy: 0.9166
# Epoch 41/100
# 4/4 [==============================] - 1s 164ms/step - loss: 0.1371 - accuracy: 0.9593 - val_loss: 0.1230 - val_accuracy: 0.9312
# Epoch 42/100
# 4/4 [==============================] - 1s 163ms/step - loss: 0.1439 - accuracy: 0.9578 - val_loss: 0.1280 - val_accuracy: 0.9295
# Epoch 43/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1360 - accuracy: 0.9592 - val_loss: 0.1430 - val_accuracy: 0.9241
# Epoch 44/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1358 - accuracy: 0.9587 - val_loss: 0.1035 - val_accuracy: 0.9454
# Epoch 45/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1347 - accuracy: 0.9571 - val_loss: 0.1718 - val_accuracy: 0.9132
# Epoch 46/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1279 - accuracy: 0.9604 - val_loss: 0.1192 - val_accuracy: 0.9347
# Epoch 47/100
# 4/4 [==============================] - 1s 164ms/step - loss: 0.1310 - accuracy: 0.9599 - val_loss: 0.1378 - val_accuracy: 0.9259
# Epoch 48/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1505 - accuracy: 0.9572 - val_loss: 0.1677 - val_accuracy: 0.9141
# Epoch 49/100
# 4/4 [==============================] - 1s 164ms/step - loss: 0.1393 - accuracy: 0.9575 - val_loss: 0.1404 - val_accuracy: 0.9278
# Epoch 50/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1452 - accuracy: 0.9537 - val_loss: 0.0616 - val_accuracy: 0.9843
# Epoch 51/100
# 4/4 [==============================] - 1s 164ms/step - loss: 0.1888 - accuracy: 0.9376 - val_loss: 0.1782 - val_accuracy: 0.9135
# Epoch 52/100
# 4/4 [==============================] - 1s 164ms/step - loss: 0.1848 - accuracy: 0.9508 - val_loss: 0.0795 - val_accuracy: 0.9812
# Epoch 53/100
# 4/4 [==============================] - 1s 161ms/step - loss: 0.2214 - accuracy: 0.9329 - val_loss: 0.0609 - val_accuracy: 0.9821
# Epoch 54/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1595 - accuracy: 0.9494 - val_loss: 0.1581 - val_accuracy: 0.9203
# Epoch 55/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1672 - accuracy: 0.9485 - val_loss: 0.0670 - val_accuracy: 0.9759
# Epoch 56/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1750 - accuracy: 0.9438 - val_loss: 0.0662 - val_accuracy: 0.9776
# Epoch 57/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1495 - accuracy: 0.9562 - val_loss: 0.1121 - val_accuracy: 0.9517
# Epoch 58/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1485 - accuracy: 0.9578 - val_loss: 0.0718 - val_accuracy: 0.9784
# Epoch 59/100
# 4/4 [==============================] - 1s 163ms/step - loss: 0.1407 - accuracy: 0.9581 - val_loss: 0.0626 - val_accuracy: 0.9813
# Epoch 60/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1385 - accuracy: 0.9592 - val_loss: 0.0902 - val_accuracy: 0.9606
# Epoch 61/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1354 - accuracy: 0.9590 - val_loss: 0.1087 - val_accuracy: 0.9429
# Epoch 62/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1336 - accuracy: 0.9599 - val_loss: 0.0919 - val_accuracy: 0.9578
# Epoch 63/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1341 - accuracy: 0.9599 - val_loss: 0.0990 - val_accuracy: 0.9509
# Epoch 64/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1271 - accuracy: 0.9608 - val_loss: 0.1175 - val_accuracy: 0.9395
# Epoch 65/100
# 4/4 [==============================] - 1s 160ms/step - loss: 0.1296 - accuracy: 0.9604 - val_loss: 0.0974 - val_accuracy: 0.9518
# Epoch 66/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1267 - accuracy: 0.9609 - val_loss: 0.1237 - val_accuracy: 0.9370
# Epoch 67/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1255 - accuracy: 0.9598 - val_loss: 0.1278 - val_accuracy: 0.9346
# Epoch 68/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1254 - accuracy: 0.9611 - val_loss: 0.1226 - val_accuracy: 0.9357
# Epoch 69/100
# 4/4 [==============================] - 1s 161ms/step - loss: 0.1216 - accuracy: 0.9617 - val_loss: 0.1217 - val_accuracy: 0.9375
# Epoch 70/100
# 4/4 [==============================] - 1s 161ms/step - loss: 0.1183 - accuracy: 0.9617 - val_loss: 0.1436 - val_accuracy: 0.9283
# Epoch 71/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1201 - accuracy: 0.9625 - val_loss: 0.1038 - val_accuracy: 0.9492
# Epoch 72/100
# 4/4 [==============================] - 1s 160ms/step - loss: 0.1529 - accuracy: 0.9457 - val_loss: 0.1428 - val_accuracy: 0.9308
# Epoch 73/100
# 4/4 [==============================] - 1s 161ms/step - loss: 0.1334 - accuracy: 0.9553 - val_loss: 0.0598 - val_accuracy: 0.9853
# Epoch 74/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1559 - accuracy: 0.9523 - val_loss: 0.1077 - val_accuracy: 0.9474
# Epoch 75/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1328 - accuracy: 0.9606 - val_loss: 0.1083 - val_accuracy: 0.9411
# Epoch 76/100
# 4/4 [==============================] - 1s 161ms/step - loss: 0.1264 - accuracy: 0.9612 - val_loss: 0.1468 - val_accuracy: 0.9253
# Epoch 77/100
# 4/4 [==============================] - 1s 161ms/step - loss: 0.1278 - accuracy: 0.9605 - val_loss: 0.1090 - val_accuracy: 0.9421
# Epoch 78/100
# 4/4 [==============================] - 1s 167ms/step - loss: 0.1266 - accuracy: 0.9609 - val_loss: 0.1107 - val_accuracy: 0.9425
# Epoch 79/100
# 4/4 [==============================] - 1s 160ms/step - loss: 0.1246 - accuracy: 0.9613 - val_loss: 0.1055 - val_accuracy: 0.9459
# Epoch 80/100
# 4/4 [==============================] - 1s 161ms/step - loss: 0.1270 - accuracy: 0.9602 - val_loss: 0.1232 - val_accuracy: 0.9360
# Epoch 81/100
# 4/4 [==============================] - 1s 160ms/step - loss: 0.1227 - accuracy: 0.9615 - val_loss: 0.1262 - val_accuracy: 0.9344
# Epoch 82/100
# 4/4 [==============================] - 1s 160ms/step - loss: 0.1205 - accuracy: 0.9620 - val_loss: 0.1156 - val_accuracy: 0.9394
# Epoch 83/100
# 4/4 [==============================] - 1s 161ms/step - loss: 0.1182 - accuracy: 0.9625 - val_loss: 0.1250 - val_accuracy: 0.9352
# Epoch 84/100
# 4/4 [==============================] - 1s 159ms/step - loss: 0.1187 - accuracy: 0.9615 - val_loss: 0.1511 - val_accuracy: 0.9253
# Epoch 85/100
# 4/4 [==============================] - 1s 161ms/step - loss: 0.1259 - accuracy: 0.9588 - val_loss: 0.1058 - val_accuracy: 0.9467
# Epoch 86/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1139 - accuracy: 0.9622 - val_loss: 0.1326 - val_accuracy: 0.9332
# Epoch 87/100
# 4/4 [==============================] - 1s 159ms/step - loss: 0.1121 - accuracy: 0.9624 - val_loss: 0.1051 - val_accuracy: 0.9469
# Epoch 88/100
# 4/4 [==============================] - 1s 160ms/step - loss: 0.1152 - accuracy: 0.9621 - val_loss: 0.1719 - val_accuracy: 0.9187
# Epoch 89/100
# 4/4 [==============================] - 1s 170ms/step - loss: 0.1218 - accuracy: 0.9601 - val_loss: 0.1120 - val_accuracy: 0.9427
# Epoch 90/100
# 4/4 [==============================] - 1s 161ms/step - loss: 0.1165 - accuracy: 0.9629 - val_loss: 0.0931 - val_accuracy: 0.9563
# Epoch 91/100
# 4/4 [==============================] - 1s 160ms/step - loss: 0.1195 - accuracy: 0.9617 - val_loss: 0.2474 - val_accuracy: 0.9011
# Epoch 92/100
# 4/4 [==============================] - 1s 162ms/step - loss: 0.1670 - accuracy: 0.9382 - val_loss: 0.0581 - val_accuracy: 0.9792
# Epoch 93/100
# 4/4 [==============================] - 1s 159ms/step - loss: 0.1820 - accuracy: 0.9426 - val_loss: 0.0795 - val_accuracy: 0.9819
# Epoch 94/100
# 4/4 [==============================] - 1s 161ms/step - loss: 0.1414 - accuracy: 0.9528 - val_loss: 0.0690 - val_accuracy: 0.9821
# Epoch 95/100
# 4/4 [==============================] - 1s 159ms/step - loss: 0.1328 - accuracy: 0.9584 - val_loss: 0.0926 - val_accuracy: 0.9558
# Epoch 96/100
# 4/4 [==============================] - 1s 157ms/step - loss: 0.1375 - accuracy: 0.9570 - val_loss: 0.0658 - val_accuracy: 0.9804
# Epoch 97/100
# 4/4 [==============================] - 1s 160ms/step - loss: 0.1402 - accuracy: 0.9588 - val_loss: 0.0828 - val_accuracy: 0.9761
# Epoch 98/100
# 4/4 [==============================] - 1s 160ms/step - loss: 0.1309 - accuracy: 0.9598 - val_loss: 0.0673 - val_accuracy: 0.9827
# Epoch 99/100
# 4/4 [==============================] - 1s 159ms/step - loss: 0.1262 - accuracy: 0.9591 - val_loss: 0.0656 - val_accuracy: 0.9826
# Epoch 100/100
# 4/4 [==============================] - 1s 159ms/step - loss: 0.1307 - accuracy: 0.9589 - val_loss: 0.0694 - val_accuracy: 0.9804

# %%
model.evaluate(X_train,Y_train)
# Out:
# 1/1 [==============================] - 1s 503ms/step - loss: 0.1447 - accuracy: 0.9541
# [0.14472827315330505, 0.9541076421737671]

# %%
print(history.history.keys())
plt.figure(figsize=(10,10))
plt.subplot(221)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')

plt.subplot(222)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
n = np.random.randint(0,10)
X_test = X_train[n]
Y_test = Y_train[n] 

plt.figure(figsize=(15,15))
plt.subplot(441)
plt.imshow(X_test)
plt.title('Testing RGB')

plt.subplot(442)
plt.imshow(Y_test)
plt.title('Testing Mask')
print(X_test.shape)
print(Y_test.shape)


testing = np.expand_dims(X_test,axis=0)
pred = model.predict(testing,verbose=1)
preds = np.argmax(pred,axis=-1)

plt.figure(figsize=(15,15))
plt.subplot(444)
plt.imshow(np.squeeze(pred>=0.5))
plt.title('Predictions')
plt.subplot(443)
plt.imshow(X_test)
plt.title('Testing RGB')
# Out:
# (512, 512, 3)
# (512, 512)
# 1/1 [==============================] - 0s 16ms/step
# Text(0.5, 1.0, 'Testing RGB')

# %%
model.save('/content/Toby_unet_building_detection_epoch100.h5')

# %%
# Out:
# 0
